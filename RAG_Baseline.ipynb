# %% [markdown]
# <a href="https://colab.research.google.com/github/VuTuanAnh0949/RAG-LangChain-Ablation-Study/blob/main/RAG_Baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Environment Setup

# %% [markdown]
# ### 1.1 Install required packages

# %%
# !pip install -q \
  "langchain>=0.2.0" \
  "langchain-core>=0.2.0" \
  "langchain-community>=0.1.0" \
  "langchain-text-splitters>=0.2.0" \
  "sentence-transformers>=2.2.0" \
  "langchain-huggingface>=0.0.1" \
  "chromadb>=0.5.0" \
  "langchain-chroma>=0.2.0" \
  "pypdf" \
  "ragas>=0.2.0" \
  "datasets>=2.14.0" \
  "pandas" \
  "matplotlib" \
  "seaborn" \
  "openai>=1.0.0" \
  "langchain-openai>=0.1.0" \
  "gdown" \
  "tiktoken" \
  "nest_asyncio"\
  "underthesea"
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 33.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.7/21.7 MB 80.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.6/329.6 kB 20.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.4/457.4 kB 28.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.7/84.7 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.9/484.9 kB 32.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 99.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.4/978.4 kB 39.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 18.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 74.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 48.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 88.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.0/220.0 kB 15.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 52.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.9/160.9 kB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.8/358.8 kB 20.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 103.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 517.7/517.7 kB 29.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.4/226.4 kB 13.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 118.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.4/128.4 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 83.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 456.8/456.8 kB 26.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 106.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 26.2 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.39.1 which is incompatible.
# google-adk 1.21.0 requires opentelemetry-api<=1.37.0,>=1.37.0, but you have opentelemetry-api 1.39.1 which is incompatible.
# google-adk 1.21.0 requires opentelemetry-sdk<=1.37.0,>=1.37.0, but you have opentelemetry-sdk 1.39.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.37.0 requires opentelemetry-exporter-otlp-proto-common==1.37.0, but you have opentelemetry-exporter-otlp-proto-common 1.39.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.37.0 requires opentelemetry-proto==1.37.0, but you have opentelemetry-proto 1.39.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.37.0 requires opentelemetry-sdk~=1.37.0, but you have opentelemetry-sdk 1.39.1 which is incompatible.

# %% [markdown]
# ### 1.2 Import libraries

# %%
import os
import re
import json
import glob
import time
import gdown
import random
import asyncio
import unicodedata
import numpy as np
import pandas as pd
import seaborn as sns
import nest_asyncio
import matplotlib.pyplot as plt
from underthesea import sent_tokenize
from matplotlib.backends.backend_pdf import PdfPages

from tqdm import tqdm
from typing import List
from openai import OpenAI
from google.colab import userdata
from langchain_chroma import Chroma

from datasets import Dataset

from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

from ragas import evaluate
from ragas.run_config import RunConfig
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    context_precision,
    context_recall
)
from ragas.embeddings import LangchainEmbeddingsWrapper

nest_asyncio.apply()
# Out:
# /tmp/ipython-input-3739442848.py:35: DeprecationWarning: Importing faithfulness from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import faithfulness
#   from ragas.metrics import (
# /tmp/ipython-input-3739442848.py:35: DeprecationWarning: Importing answer_relevancy from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import answer_relevancy
#   from ragas.metrics import (
# /tmp/ipython-input-3739442848.py:35: DeprecationWarning: Importing context_precision from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_precision
#   from ragas.metrics import (
# /tmp/ipython-input-3739442848.py:35: DeprecationWarning: Importing context_recall from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_recall
#   from ragas.metrics import (

# %% [markdown]
# ### 1.3 Set global seed for reproducibility (SEED = 42)

# %%
SEED = 42

def set_global_seed(seed_value: int = 42):
    random.seed(seed_value)
    np.random.seed(seed_value)
    os.environ['PYTHONHASHSEED'] = str(seed_value)
    print(f"Global seed set to {seed_value}")

set_global_seed(SEED)
# Out:
# Global seed set to 42

# %% [markdown]
# ### 1.4 Configure API Keys

# %%
os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")

# os.environ["OPENAI_API_KEY"] = ""
OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]

print("OpenAI API Key configured successfully")
# Out:
# OpenAI API Key configured successfully

# %% [markdown]
# ### 1.5 Batch Processing Configuration

# %%
BATCH_SIZE = 32
EMBEDDING_BATCH_SIZE = 100

LLM_MODEL = "gpt-4o-mini"
EMBEDDING_MODEL = "text-embedding-3-small"

EVAL_SAMPLE_SIZE = None
EVAL_MAX_WORKERS = 64
EVAL_TIMEOUT = 180

print(f"Configuration:")
print(f"  - LLM Model: {LLM_MODEL}")
print(f"  - Embedding Model: {EMBEDDING_MODEL}")
print(f"  - Batch Size: {BATCH_SIZE}")
print(f"  - RAGAS Eval Workers: {EVAL_MAX_WORKERS}")
print(f"  - Eval Sample Size: {'ALL' if EVAL_SAMPLE_SIZE is None else EVAL_SAMPLE_SIZE}")
# Out:
# Configuration:
#   - LLM Model: gpt-4o-mini
#   - Embedding Model: text-embedding-3-small
#   - Batch Size: 32
#   - RAGAS Eval Workers: 64
#   - Eval Sample Size: ALL

# %% [markdown]
# ## 2. Data Preparation

# %% [markdown]
# ### 2.1 Download data

# %%
# !gdown 1Ebcv-0kq6_eF6QYfIMSL6ZXQUnETnWKW
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Ebcv-0kq6_eF6QYfIMSL6ZXQUnETnWKW
# From (redirected): https://drive.google.com/uc?id=1Ebcv-0kq6_eF6QYfIMSL6ZXQUnETnWKW&confirm=t&uuid=7a319f6f-4081-4a9c-87b8-77711435d829
# To: /content/RAG_DATA.zip
# 100% 133M/133M [00:02<00:00, 45.6MB/s]

# %%
file_id = "1Ebcv-0kq6_eF6QYfIMSL6ZXQUnETnWKW"
zip_path = "/content/data.zip"
gdown.download(f"https://drive.google.com/uc?id={file_id}", zip_path, quiet=False)

# !unzip -o /content/data.zip
DATA_DIR = "RAG_DATA"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Ebcv-0kq6_eF6QYfIMSL6ZXQUnETnWKW
# From (redirected): https://drive.google.com/uc?id=1Ebcv-0kq6_eF6QYfIMSL6ZXQUnETnWKW&confirm=t&uuid=50a0fc93-1395-48cb-adb8-f4c58e3620aa
# To: /content/data.zip
# 100%|██████████| 133M/133M [00:02<00:00, 54.9MB/s]
# Archive:  /content/data.zip
#    creating: RAG_DATA/
#   inflating: RAG_DATA/AI_Agents_Smolagents.pdf
#   inflating: RAG_DATA/AI_Image_Gen_Edit_CFM.pdf
#   inflating: RAG_DATA/AI_Linear_Algebra_NumPy_Practice.pdf
#   inflating: RAG_DATA/AI_Multi_Agent_Supervisor.pdf
#   inflating: RAG_DATA/AI_Problem_Solving.pdf
#   inflating: RAG_DATA/AI_Problem_Solving_Framework.pdf
#   inflating: RAG_DATA/AI_Vietnamese_Poetry.pdf
#   inflating: RAG_DATA/Applied_Statistics_AI.pdf
#   inflating: RAG_DATA/CNN_Exercise.pdf
#   inflating: RAG_DATA/Effective_Data_Presentation.pdf
#   inflating: RAG_DATA/Emoji_Generation_Stable_Diffusion.pdf
#   inflating: RAG_DATA/Git_DS_Roadmap.pdf
#   inflating: RAG_DATA/Hand_Gesture_Control_System_Tutorial.pdf
#   inflating: RAG_DATA/Interpolation_Missing_Data.pdf
#   inflating: RAG_DATA/LangChain_RAG_PDF_QA_Guide.pdf
#   inflating: RAG_DATA/LLM_Alignment_DPO.pdf
#   inflating: RAG_DATA/LLM_IT_SAT_Reading.pdf
#   inflating: RAG_DATA/LLM_Math_Reasoning_GRPO.pdf
#   inflating: RAG_DATA/LoRA_QLoRA_LLM_Tutorial.pdf
#   inflating: RAG_DATA/MiniGPT4V_Fine_Tuning_Tutorial.pdf
#   inflating: RAG_DATA/MT_Low_Resource_Fine_tuning.pdf
#   inflating: RAG_DATA/Naive_Bayes_Classification_Exercise.pdf
#   inflating: RAG_DATA/Naive_Bayes_Classifiers.pdf
#   inflating: RAG_DATA/NLP_Text_Classification.pdf
#   inflating: RAG_DATA/OOP_DS_Exercises.pdf
#   inflating: RAG_DATA/OOP_Guide.pdf
#   inflating: RAG_DATA/PDF_QA_RAG_LLM.pdf
#   inflating: RAG_DATA/PEFT_LLM_MCQA.pdf
#   inflating: RAG_DATA/Python_AI_ML.pdf
#   inflating: RAG_DATA/Python_Basics_Quiz.pdf
#   inflating: RAG_DATA/Python_Dictionary_NLP_AI.pdf
#   inflating: RAG_DATA/Python_DS_Best_Practices.pdf
#   inflating: RAG_DATA/Python_List_AI_ML_Lab.pdf
#   inflating: RAG_DATA/Python_Naming_Conventions.pdf
#   inflating: RAG_DATA/Python_OOP_Best_Practices.pdf
#   inflating: RAG_DATA/Python_OOP_Errors.pdf
#   inflating: RAG_DATA/Python_Variables_Memory.pdf
#   inflating: RAG_DATA/Python_Word_Cloud.pdf
#   inflating: RAG_DATA/ReAct_Plan_Execute_LangGraph.pdf
#   inflating: RAG_DATA/Spam_Classification_Project.pdf
#   inflating: RAG_DATA/Streamlit_Student_Scores_Analysis.pdf
#   inflating: RAG_DATA/Streamlit_Web_App_Guide.pdf
#   inflating: RAG_DATA/Tool_Calling_LLM_Intro.pdf
#   inflating: RAG_DATA/Typo_Correction_QWERTY.pdf
#   inflating: RAG_DATA/Vietnamese_Chatbot_RLHF.pdf

# %% [markdown]
# ### 2.2 Download testing file

# %%
file_id = "1a5RL7ex88w_5tZ1g6R31QTrfibvxqT_Q"
gdown.download(f"https://drive.google.com/uc?id={file_id}", quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1a5RL7ex88w_5tZ1g6R31QTrfibvxqT_Q
# To: /content/testset.json
# 100%|██████████| 312k/312k [00:00<00:00, 86.3MB/s]
# 'testset.json'

# %% [markdown]
# ## 3. Model Configuration (API-based)

# %%
def get_llm(
    model_name: str = LLM_MODEL,
    temperature: float = 0.0,
    max_tokens: int = 8192,
    seed: int = SEED,
):
    llm = ChatOpenAI(
        model=model_name,
        temperature=temperature,
        max_tokens=max_tokens,
        seed=seed,
        api_key=OPENAI_API_KEY,
    )
    print(f"✓ LLM initialized: {model_name} (seed={seed})")
    return llm


def get_embeddings(
    model_name: str = EMBEDDING_MODEL,
    chunk_size: int = EMBEDDING_BATCH_SIZE,
):
    embeddings = OpenAIEmbeddings(
        model=model_name,
        api_key=OPENAI_API_KEY,
        chunk_size=chunk_size,
    )
    print(f"Embeddings initialized: {model_name} (batch_size={chunk_size})")
    return embeddings

# %% [markdown]
# ## 4. RAG Components

# %% [markdown]
# ### 4.1 Define Vietnamese text cleaning function

# %%
def clean_vietnamese_text(text: str) -> str:
    text = unicodedata.normalize('NFC', text)
    text = "".join(
        char for char in text
        if not unicodedata.category(char).startswith('C') or char in '\n\t'
    )
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'\n\s*\n', '\n', text)
    return text.strip()

# %% [markdown]
# ### 4.2 Define document loader and text splitter

# %%
class SimpleLoader:
    def load_pdf(self, pdf_file: str):
        docs = PyPDFLoader(pdf_file, extract_images=True).load()
        for doc in docs:
            doc.page_content = clean_vietnamese_text(doc.page_content)
        return docs

    def load_dir(self, dir_path: str) -> List:
        pdf_files = glob.glob(f"{dir_path}/*.pdf")
        if not pdf_files:
            raise ValueError(f"No PDF files found in {dir_path}")

        all_docs = []
        for pdf_file in tqdm(pdf_files, desc="Loading PDFs"):
            try:
                all_docs.extend(self.load_pdf(pdf_file))
            except Exception as e:
                pass
        return all_docs


class TextSplitter:
    def __init__(
        self,
        chunk_size: int = 1024,
        chunk_overlap: int = 128,
    ):
        self.splitter = RecursiveCharacterTextSplitter(
            separators=["\n\n", "\n", " ", ""],
            chunk_size=chunk_size,
            chunk_overlap=chunk_overlap,
            length_function=len,
        )

    def split(self, documents):
        return self.splitter.split_documents(documents)

# %% [markdown]
# ### 4.3 Define vector database class (API Embeddings)

# %%
class VectorDB:
    def __init__(
        self,
        documents=None,
        embedding=None,
        collection_name: str = "vietnamese_docs",
        persist_dir: str = "/content/chroma_data",
    ):
        self.persist_dir = persist_dir
        self.collection_name = collection_name
        self.embedding = embedding or get_embeddings()
        self.db = self._build_db(documents)

    def _build_db(self, documents):
        if documents is None or len(documents) == 0:
            db = Chroma(
                collection_name=self.collection_name,
                embedding_function=self.embedding,
                persist_directory=self.persist_dir,
            )
        else:
            print(f"Building vector database with {len(documents)} documents...")
            db = Chroma.from_documents(
                documents=documents,
                embedding=self.embedding,
                collection_name=self.collection_name,
                persist_directory=self.persist_dir,
            )
            print(f"✓ Vector database built successfully!")
        return db

    def get_retriever(self, search_kwargs: dict = None):
        if search_kwargs is None:
            search_kwargs = {"k": 3}

        return self.db.as_retriever(
            search_type="similarity",
            search_kwargs=search_kwargs,
        )

# %% [markdown]
# ### 4.4 Define RAG pipeline with batch processing

# %%
class FocusedAnswerParser(StrOutputParser):
    def parse(self, text: str) -> str:
        text = (text or "").strip()
        if "[TRẢ LỜI]:" in text:
            answer = text.split("[TRẢ LỜI]:")[-1].strip()
        else:
            answer = text

        answer = re.sub(r'^\s*[•\-\*]\s*', '', answer, flags=re.MULTILINE)
        answer = re.sub(r'\n+', ' ', answer).strip()
        return answer


class BatchRAG:
    def __init__(self, llm, batch_size: int = BATCH_SIZE):
        self.llm = llm
        self.batch_size = batch_size
        self.prompt_template = """Bạn là trợ lý AI phân tích tài liệu tiếng Việt.

[TÀI LIỆU]:
{context}

[CÂU HỎI]:
{question}

Hãy trả lời dựa trên tài liệu. Nếu tài liệu không có thông tin, nói rõ "Không có thông tin".
[TRẢ LỜI]:"""
        self.prompt = PromptTemplate.from_template(self.prompt_template)
        self.answer_parser = FocusedAnswerParser()

    def _format_docs(self, docs):
        formatted = []
        seen = set()
        for doc in docs:
            content = (doc.page_content or "").strip()
            if content and len(content) > 40 and content not in seen:
                formatted.append(content)
                seen.add(content)
        return "\n\n".join(formatted)

    def get_chain(self, retriever):
        def format_docs(docs):
            return self._format_docs(docs)

        rag_chain = (
            {"context": retriever | format_docs, "question": RunnablePassthrough()}
            | self.prompt
            | self.llm
            | self.answer_parser
        )
        return rag_chain

    def batch_retrieve(self, questions: List[str], retriever) -> List[dict]:
        all_contexts = []
        for question in tqdm(questions, desc="Retrieving documents"):
            docs = retriever.invoke(question)
            contexts = [(doc.page_content or "") for doc in docs]
            formatted_context = self._format_docs(docs)
            all_contexts.append({
                "question": question,
                "contexts": contexts,
                "formatted_context": formatted_context
            })
        return all_contexts

    def batch_generate(self, prompts: List[str]) -> List[str]:
        from langchain_core.messages import HumanMessage

        all_answers = []
        for i in tqdm(range(0, len(prompts), self.batch_size), desc="Generating answers"):
            batch = prompts[i:i + self.batch_size]

            messages_batch = [[HumanMessage(content=p)] for p in batch]
            batch_results = self.llm.batch(messages_batch)

            for result in batch_results:
                answer = self.answer_parser.parse(result.content)
                all_answers.append(answer)

        return all_answers

    def answer_with_contexts_batch(self, questions: List[str], retriever):
        print(f"Processing {len(questions)} questions in batches of {self.batch_size}...")
        retrieved_data = self.batch_retrieve(questions, retriever)
        prompts = [
            self.prompt.format(
                context=data["formatted_context"],
                question=data["question"]
            )
            for data in retrieved_data
        ]
        answers = self.batch_generate(prompts)

        results = []
        for data, answer in zip(retrieved_data, answers):
            results.append({
                "answer": answer,
                "contexts": data["contexts"]
            })

        return results

# %% [markdown]
# ## 5. RAG System Initialization

# %%
set_global_seed(SEED)

llm = get_llm(model_name=LLM_MODEL, seed=SEED)
embeddings = get_embeddings(model_name=EMBEDDING_MODEL, chunk_size=EMBEDDING_BATCH_SIZE)

loader = SimpleLoader()
text_splitter = TextSplitter(chunk_size=1024, chunk_overlap=128)

raw_docs = loader.load_dir(DATA_DIR)
split_docs = text_splitter.split(raw_docs)
print(f"Total documents: {len(raw_docs)}, Split chunks: {len(split_docs)}")

vdb = VectorDB(documents=split_docs, embedding=embeddings)
retriever = vdb.get_retriever(search_kwargs={"k": 3})

rag = BatchRAG(llm, batch_size=BATCH_SIZE)
rag_chain = rag.get_chain(retriever)

print("\n" + "="*50)
print("RAG System initialized successfully!")
print(f"  - LLM: {LLM_MODEL} (API)")
print(f"  - Embeddings: {EMBEDDING_MODEL} (API)")
print(f"  - Batch Size: {BATCH_SIZE}")
print(f"  - Seed: {SEED}")
print("="*50)
# Out:
# Global seed set to 42
# ✓ LLM initialized: gpt-4o-mini (seed=42)
# Embeddings initialized: text-embedding-3-small (batch_size=100)
# Loading PDFs:  60%|██████    | 27/45 [00:37<00:19,  1.09s/it]WARNING:pypdf._reader:Ignoring wrong pointing object 7 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 9 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 17 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 25 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 27 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 29 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 31 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 40 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 42 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 49 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 51 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 53 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 55 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 57 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 68 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 70 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 77 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 79 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 117 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 129 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 143 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 152 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 155 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 243 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 307 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 354 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 399 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 401 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 417 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 419 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 423 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 430 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 433 0 (offset 0)
# Loading PDFs:  64%|██████▍   | 29/45 [00:40<00:18,  1.15s/it]WARNING:pypdf._reader:Ignoring wrong pointing object 8 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 10 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 21 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 23 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 25 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 27 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 29 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 31 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 33 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 35 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 37 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 49 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 52 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 54 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 67 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 82 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 85 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 104 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 132 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 160 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 162 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 196 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 203 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 205 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 215 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 241 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 268 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 296 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 306 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 345 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 388 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 410 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 430 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 457 0 (offset 0)
# Loading PDFs: 100%|██████████| 45/45 [01:00<00:00,  1.34s/it]
# Total documents: 1372, Split chunks: 2184
# Building vector database with 2184 documents...
# ✓ Vector database built successfully!
#
# ==================================================
# RAG System initialized successfully!
#   - LLM: gpt-4o-mini (API)
#   - Embeddings: text-embedding-3-small (API)
#   - Batch Size: 32
#   - Seed: 42
# ==================================================

# %% [markdown]
# ## 6. Evaluation

# %% [markdown]
# ### 6.1 Load testing data from JSON

# %%
testset_path = 'testset.json'

with open(testset_path, 'r', encoding='utf-8') as f:
    testset_data = json.load(f)

test_df = pd.DataFrame([
    {
        'user_input': item['user_input'],
        'reference': item['reference'],
        'reference_contexts': item['reference_contexts']
    }
    for item in testset_data
])

print(f"Loaded {len(test_df)} test questions from testset.json")
display(test_df.head())
# Out:
# Loaded 52 test questions from testset.json
#                                           user_input  \
# 0  Máy học là gì và nó có vai trò gì trong phân l...
# 1  Cơ sở dữ liệu Vector là gì và nó được sử dụng ...
# 2  What is the significance of the FA Cup in the ...
# 3  What libraries are commonly used in AI VIET NA...
# 4  What are the key steps involved in the data pr...
#
#                                            reference  \
# 0  Máy học là một lĩnh vực phổ biến trong phân lo...
# 1  Cơ sở dữ liệu Vector được sử dụng trong việc x...
# 2  The FA Cup is mentioned in a spam message that...
# 3  In AI VIET NAM, commonly used libraries for na...
# 4  The key steps involved in the data preprocessi...
#
#                                   reference_contexts
# 0  [I. Giới thiệu** **Text Classification (Tạm dị...
# 1  [II.2. Cài đặt và Import thư viện . . . . . . ...
# 2  [. . . . . . . . . . . . . . . . . . . 14 III....
# 3  [Text FA to 87121 to receive entr...| |spam|Fr...
# 4  [phần đặc trưng và nhãn, sau khi có dataframe,...

# %% [markdown]
# ### 6.2 Run batch predictions on test questions (API)

# %%
set_global_seed(SEED)

print(f"LLM: {LLM_MODEL}")
print(f"Batch size: {BATCH_SIZE}")

questions = test_df['user_input'].tolist()

start_time = time.time()
batch_results = rag.answer_with_contexts_batch(questions, retriever)
elapsed_time = time.time() - start_time

print(f"Inference completed in {elapsed_time:.2f} seconds")
print(f"Average time per question: {elapsed_time/len(questions):.2f} seconds")

results = []
for idx, (result, (_, row)) in enumerate(zip(batch_results, test_df.iterrows())):
    results.append({
        "user_input": row['user_input'],
        "response": result["answer"],
        "retrieved_contexts": result["contexts"],
        "reference": row.get('reference', ''),
        "reference_contexts": row.get('reference_contexts', [])
    })

eval_df = pd.DataFrame(results)
print(f"Collected {len(eval_df)} predictions")
display(eval_df.head())
# Out:
# Global seed set to 42
# LLM: gpt-4o-mini
# Batch size: 32
# Processing 52 questions in batches of 32...
# Retrieving documents: 100%|██████████| 52/52 [00:14<00:00,  3.55it/s]
# Generating answers: 100%|██████████| 2/2 [00:40<00:00, 20.38s/it]
# Inference completed in 55.41 seconds
# Average time per question: 1.07 seconds
# Collected 52 predictions
#                                           user_input  \
# 0  Máy học là gì và nó có vai trò gì trong phân l...
# 1  Cơ sở dữ liệu Vector là gì và nó được sử dụng ...
# 2  What is the significance of the FA Cup in the ...
# 3  What libraries are commonly used in AI VIET NA...
# 4  What are the key steps involved in the data pr...
#
#                                             response  \
# 0  Máy học (học máy) là một nhánh của trí tuệ nhâ...
# 1  Cơ sở dữ liệu Vector là một hệ thống lưu trữ c...
# 2                                Không có thông tin.
# 3  Các thư viện thường được sử dụng trong AI VIET...
# 4                                Không có thông tin.
#
#                                   retrieved_contexts  \
# 0  [dùng thư viện ngoài. Bạn sẽ học cách biểu diễ...
# 1  [AI VIET NAM (AIO2025) aivietnam.edu.vn III. X...
# 2  [AI VIET NAM (AIO2025) aivietnam.edu.vn II. Xâ...
# 3  [AI VIET NAM (AIO2025) aivietnam.edu.vn • stri...
# 4  [AI VIETNAM (AIO2024) aivietnam.edu.vn • Crawl...
#
#                                            reference  \
# 0  Máy học là một lĩnh vực phổ biến trong phân lo...
# 1  Cơ sở dữ liệu Vector được sử dụng trong việc x...
# 2  The FA Cup is mentioned in a spam message that...
# 3  In AI VIET NAM, commonly used libraries for na...
# 4  The key steps involved in the data preprocessi...
#
#                                   reference_contexts
# 0  [I. Giới thiệu** **Text Classification (Tạm dị...
# 1  [II.2. Cài đặt và Import thư viện . . . . . . ...
# 2  [. . . . . . . . . . . . . . . . . . . 14 III....
# 3  [Text FA to 87121 to receive entr...| |spam|Fr...
# 4  [phần đặc trưng và nhãn, sau khi có dataframe,...

# %% [markdown]
# ### 6.3 Evaluate RAG with RAGAS metrics

# %%
if EVAL_SAMPLE_SIZE is not None:
    eval_subset = eval_df.sample(n=min(EVAL_SAMPLE_SIZE, len(eval_df)), random_state=SEED)
    print(f"Quick evaluation mode: Using {len(eval_subset)} samples")
else:
    eval_subset = eval_df
    print(f"Full evaluation: Using all {len(eval_subset)} samples")

eval_dataset = Dataset.from_pandas(eval_subset.reset_index(drop=True))

wrapped_embeddings = LangchainEmbeddingsWrapper(
    OpenAIEmbeddings(model='text-embedding-3-small')
)

run_config = RunConfig(
    max_workers=EVAL_MAX_WORKERS,
    timeout=EVAL_TIMEOUT,
    max_retries=1,
    max_wait=60,
)

print(f"Running RAGAS evaluation...")
print(f"   - Parallel workers: {EVAL_MAX_WORKERS}")
print(f"   - Samples: {len(eval_subset)}")

start_time = time.time()

ragas_results = evaluate(
    dataset=eval_dataset,
    metrics=[
        faithfulness,
        answer_relevancy,
        context_precision,
        context_recall
    ],
    embeddings=wrapped_embeddings,
    run_config=run_config,
    raise_exceptions=False,
)

eval_time = time.time() - start_time
print(f"\nEvaluation completed in {eval_time:.1f} seconds")
print(f"  Average: {eval_time/len(eval_subset):.2f}s per sample")

print("=== RAGAS SCORES ===")
print(ragas_results)
# Out:
# /tmp/ipython-input-3311990745.py:10: DeprecationWarning: LangchainEmbeddingsWrapper is deprecated and will be removed in a future version. Use the modern embedding providers instead: embedding_factory('openai', model='text-embedding-3-small', client=openai_client) or from ragas.embeddings import OpenAIEmbeddings, GoogleEmbeddings, HuggingFaceEmbeddings
#   wrapped_embeddings = LangchainEmbeddingsWrapper(
# Full evaluation: Using all 52 samples
# Running RAGAS evaluation...
#    - Parallel workers: 64
#    - Samples: 52
# Evaluating:   0%|          | 0/208 [00:00<?, ?it/s]
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# ERROR:ragas.executor:Exception raised in Job[80]: InstructorRetryException(<failed_attempts>
#
# <generation number="1">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-CsQPpFsNTPZXSlIe1QOZljPrC7mMh', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "statements": [\n        {\n            "statement": "Để xác định đúng vấn đề trong dự án AI, cần thực hiện các bước sau.",\n            "reason": "The context discusses the importance of correctly identifying the problem in AI projects but does not specify the steps to do so.",\n            "verdict": 0\n        },\n        {\n            "statement": "Bắt đầu từ vấn đề kinh doanh cụ thể là bước đầu tiên.",\n            "reason": "The context implies that starting from a specific business problem is important, but it does not explicitly state that it is the first step.",\n            "verdict": 0\n        },\n        {\n            "statement": "Thay vì tập trung vào triệu chứng, cần xác định rõ ràng vấn đề gốc rễ mà dự án muốn giải quyết.",\n            "reason": "The context mentions the need to focus on root causes rather than symptoms, which supports this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Phân tích tìm nguyên nhân gốc rễ là bước thứ hai.",\n            "reason": "The context discusses analyzing root causes but does not specify it as the second step.",\n            "verdict": 0\n        },\n        {\n            "statement": "Phân tích tìm nguyên nhân gốc rễ giúp hiểu rõ hơn về vấn đề.",\n            "reason": "The context supports this statement by indicating that analyzing root causes aids in understanding the problem better.",\n            "verdict": 1\n        },\n        {\n            "statement": "Phân tích tìm nguyên nhân gốc rễ tránh việc chỉ giải quyết các triệu chứng bề ngoài.",\n            "reason": "The context emphasizes the importance of addressing root causes to avoid just treating symptoms, which validates this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Áp dụng tiêu chí SMART là bước thứ ba.",\n            "reason": "The context mentions applying SMART criteria but does not specify it as the third step.",\n            "verdict": 0\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa một cách cụ thể.",\n            "reason": "The context states that SMART criteria ensure specific problem definitions, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa là đo lường được.",\n            "reason": "The context indicates that SMART criteria include measurability, which supports this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa là có thể đạt được.",\n            "reason": "The context mentions that SMART criteria include achievability, which supports this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa là thực tế.",\n            "reason": "The context states that SMART criteria ensure realism in problem definitions, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa là có thời hạn rõ ràng.",\n            "reason": "The context mentions that SMART criteria include time-bound aspects, which supports this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Xác định rõ KPI đo lường là bước thứ tư.",\n            "reason": "The context discusses the importance of establishing clear KPIs but does not specify it as the fourth step.",\n            "verdict": 0\n        },\n        {\n            "statement": "Thiết lập các chỉ số hiệu suất chính (KPIs) phù hợp để đánh giá hiệu quả của giải pháp AI là cần thiết.",\n            "reason": "The context emphasizes the necessity of e ...
# </completion>
# </generation>
#
# <generation number="2">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-CsQQ82fCgnV1w4zJWHxh5NUdpMylN', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "statements": [\n        {\n            "statement": "Để xác định đúng vấn đề trong dự án AI, cần thực hiện các bước sau.",\n            "reason": "The context discusses the importance of correctly identifying the problem in AI projects but does not specify the steps to do so.",\n            "verdict": 0\n        },\n        {\n            "statement": "Bắt đầu từ vấn đề kinh doanh cụ thể là bước đầu tiên.",\n            "reason": "The context implies that starting from a specific business problem is important, but it does not explicitly state that it is the first step.",\n            "verdict": 0\n        },\n        {\n            "statement": "Thay vì tập trung vào triệu chứng, cần xác định rõ ràng vấn đề gốc rễ mà dự án muốn giải quyết.",\n            "reason": "The context mentions the need to focus on root causes rather than symptoms, which supports this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Phân tích tìm nguyên nhân gốc rễ là bước thứ hai.",\n            "reason": "The context discusses analyzing root causes but does not specify it as the second step.",\n            "verdict": 0\n        },\n        {\n            "statement": "Phân tích tìm nguyên nhân gốc rễ giúp hiểu rõ hơn về vấn đề.",\n            "reason": "The context implies that analyzing root causes aids in understanding the problem better, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Phân tích tìm nguyên nhân gốc rễ tránh việc chỉ giải quyết các triệu chứng bề ngoài.",\n            "reason": "The context states that focusing on root causes prevents merely addressing superficial symptoms, which supports this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Áp dụng tiêu chí SMART là bước thứ ba.",\n            "reason": "The context mentions applying SMART criteria but does not specify it as the third step.",\n            "verdict": 0\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa một cách cụ thể.",\n            "reason": "The context states that SMART criteria ensure specific problem definitions, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa là đo lường được.",\n            "reason": "The context mentions that SMART criteria ensure the problem is measurable, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa là có thể đạt được.",\n            "reason": "The context states that SMART criteria ensure the problem is achievable, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa là thực tế.",\n            "reason": "The context mentions that SMART criteria ensure the problem is realistic, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa là có thời hạn rõ ràng.",\n            "reason": "The context states that SMART criteria ensure the problem has a clear deadline, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Xác định rõ KPI đo lường là bước thứ tư.",\n            "reason": "The context discusses establishing clear KPIs but does not specify it as the fourth step.",\n            "verdict": 0\n        },\n        {\n            "statement": "Thiết lập các chỉ số hiệu suất chính (KPIs) phù hợp để đánh giá hiệu quả của giải pháp AI là cần thiết.",\n            "reason": "The context states that establishing appropriate  ...
# </completion>
# </generation>
#
# <generation number="3">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-CsQQSyIQJ3LMRBnvw4v8apojrb1xo', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "statements": [\n        {\n            "statement": "Để xác định đúng vấn đề trong dự án AI, cần thực hiện các bước sau.",\n            "reason": "The context discusses the importance of correctly identifying the problem in AI projects but does not specify the steps to do so.",\n            "verdict": 0\n        },\n        {\n            "statement": "Bắt đầu từ vấn đề kinh doanh cụ thể là bước đầu tiên.",\n            "reason": "The context mentions starting from a specific business problem as part of the process, implying it is an important step.",\n            "verdict": 1\n        },\n        {\n            "statement": "Thay vì tập trung vào triệu chứng, cần xác định rõ ràng vấn đề gốc rễ mà dự án muốn giải quyết.",\n            "reason": "The context emphasizes the need to focus on root causes rather than symptoms, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Phân tích tìm nguyên nhân gốc rễ là bước thứ hai.",\n            "reason": "The context does not explicitly state the order of steps, so this cannot be directly inferred.",\n            "verdict": 0\n        },\n        {\n            "statement": "Phân tích tìm nguyên nhân gốc rễ giúp hiểu rõ hơn về vấn đề.",\n            "reason": "The context implies that analyzing root causes aids in understanding the problem better, thus supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Phân tích tìm nguyên nhân gốc rễ tránh việc chỉ giải quyết các triệu chứng bề ngoài.",\n            "reason": "The context mentions that focusing on root causes prevents merely addressing superficial symptoms, validating this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Áp dụng tiêu chí SMART là bước thứ ba.",\n            "reason": "The context discusses SMART criteria but does not specify the order of steps, making this statement unverifiable.",\n            "verdict": 0\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa một cách cụ thể.",\n            "reason": "The context states that SMART criteria ensure specific definitions of problems, thus supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa là đo lường được.",\n            "reason": "The context indicates that SMART criteria include measurability, validating this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa là có thể đạt được.",\n            "reason": "The context mentions that SMART criteria ensure achievability, thus supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa là thực tế.",\n            "reason": "The context states that SMART criteria ensure realism in problem definitions, validating this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa là có thời hạn rõ ràng.",\n            "reason": "The context mentions that SMART criteria include clear deadlines, thus supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Xác định rõ KPI đo lường là bước thứ tư.",\n            "reason": "The context discusses the importance of establishing KPIs but does not specify the order of steps, making this statement unverifiable.",\n            "verdict": 0\n        },\n        {\n            "statement": "Thiết lập các chỉ số hiệu suất chính (KPIs) phù hợp để đánh giá hiệu quả của giải pháp AI là cần thiết.",\n            "reason": "T ...
# </completion>
# </generation>
#
# </failed_attempts>
#
# <last_exception>
#     The output is incomplete due to a max_tokens length limit.
# </last_exception>)
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# ERROR:ragas.executor:Exception raised in Job[100]: InstructorRetryException(<failed_attempts>
#
# <generation number="1">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-CsQSsj3FOLTwfXZkcdqauXSoiCEkd', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "statements": [\n        {\n            "statement": "Việc điều chỉnh Adapter-tuning và kỹ thuật LoRA có thể giúp tối ưu hóa tài nguyên trong quá trình fine-tuning các mô hình ngôn ngữ lớn.",\n            "reason": "The context discusses how LoRA and PEFT techniques optimize resource usage during fine-tuning of large language models.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc điều chỉnh Adapter-tuning và kỹ thuật LoRA giúp tối ưu hóa tài nguyên thông qua các phương pháp sau.",\n            "reason": "The context mentions that LoRA and PEFT techniques optimize resources, but does not list specific methods in this statement.",\n            "verdict": 0\n        },\n        {\n            "statement": "Giảm số lượng tham số cần điều chỉnh là một trong những phương pháp.",\n            "reason": "The context states that reducing the number of parameters to adjust is a method used in LoRA and PEFT techniques.",\n            "verdict": 1\n        },\n        {\n            "statement": "Thay vì cập nhật toàn bộ các tham số của mô hình, LoRA tập trung vào việc tìm kiếm một cấu trúc có hạng thấp cho các ma trận trọng số.",\n            "reason": "The context explicitly states that LoRA focuses on finding a low-rank structure for weight matrices instead of updating all parameters.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc tìm kiếm cấu trúc có hạng thấp giúp giảm thiểu số lượng tham số cần điều chỉnh.",\n            "reason": "The context explains that searching for a low-rank structure minimizes the number of parameters that need to be adjusted.",\n            "verdict": 1\n        },\n        {\n            "statement": "Giảm thiểu số lượng tham số cần điều chỉnh giúp tiết kiệm tài nguyên.",\n            "reason": "The context implies that reducing the number of parameters to adjust leads to resource savings.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tối ưu hóa về mặt tài nguyên và thời gian là một phương pháp khác.",\n            "reason": "The context mentions optimizing resources and time as a benefit of using LoRA, but does not specify it as a separate method.",\n            "verdict": 0\n        },\n        {\n            "statement": "Kỹ thuật LoRA cho phép huấn luyện các mô hình ngôn ngữ lớn một cách tối ưu.",\n            "reason": "The context states that LoRA allows for optimal training of large language models.",\n            "verdict": 1\n        },\n        {\n            "statement": "Kỹ thuật LoRA giúp tận dụng tối đa kiến thức ban đầu từ dữ liệu lớn mà không cần phải huấn luyện lại toàn bộ mô hình.",\n            "reason": "The context explains that LoRA allows leveraging initial knowledge from large datasets without retraining the entire model.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc không cần huấn luyện lại toàn bộ mô hình không chỉ tiết kiệm thời gian mà còn giảm thiểu yêu cầu về GPU mạnh và bộ nhớ lớn.",\n            "reason": "The context states that not retraining the entire model saves time and reduces the need for powerful GPUs and large memory.",\n            "verdict": 1\n        },\n        {\n            "statement": "Giảm thiểu nguy cơ quá khớp (overfitting) là một phương pháp khác.",\n            "reason": "The context mentions that reducing overfitting risk is a benefit of the techniques discussed, but does not specify it as a separate method.",\n            "verdict": 0\n        },\n        {\n            "statement": "Việc chỉ điều chỉnh một số lượng nhỏ tham số giúp giảm nguy cơ quá khớp với dữ liệu huấn luyện.",\n            "reason": "The context implies that adjusting only a small number of parameters helps reduce the risk of overfitting.",\n            "verdict": 1\n    ...
# </completion>
# </generation>
#
# <generation number="2">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-CsQTFdAiANuDSv7p6oQ9C8V4pOUl9', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "statements": [\n        {\n            "statement": "Việc điều chỉnh Adapter-tuning và kỹ thuật LoRA có thể giúp tối ưu hóa tài nguyên trong quá trình fine-tuning các mô hình ngôn ngữ lớn.",\n            "reason": "The context discusses how LoRA and PEFT techniques optimize resource usage during fine-tuning, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc điều chỉnh Adapter-tuning và kỹ thuật LoRA giúp tối ưu hóa tài nguyên thông qua các phương pháp sau.",\n            "reason": "The context mentions the optimization of resources through techniques like LoRA, but does not list specific methods, making this statement not directly inferred.",\n            "verdict": 0\n        },\n        {\n            "statement": "Giảm số lượng tham số cần điều chỉnh là một trong những phương pháp.",\n            "reason": "The context states that reducing the number of parameters is a key aspect of LoRA, thus this statement can be inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Thay vì cập nhật toàn bộ các tham số của mô hình, LoRA tập trung vào việc tìm kiếm một cấu trúc có hạng thấp cho các ma trận trọng số.",\n            "reason": "This statement is directly supported by the context, which explains LoRA\'s focus on low-rank structures instead of updating all parameters.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc tìm kiếm cấu trúc có hạng thấp giúp giảm thiểu số lượng tham số cần điều chỉnh.",\n            "reason": "The context explicitly states that searching for low-rank structures minimizes the number of parameters to adjust, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Giảm thiểu số lượng tham số cần điều chỉnh giúp tiết kiệm tài nguyên.",\n            "reason": "The context implies that reducing the number of parameters leads to resource savings, thus this statement can be inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tối ưu hóa về mặt tài nguyên và thời gian là một phương pháp khác.",\n            "reason": "The context mentions optimizing resources and time as a benefit of LoRA, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Kỹ thuật LoRA cho phép huấn luyện các mô hình ngôn ngữ lớn một cách tối ưu.",\n            "reason": "The context states that LoRA allows for optimal training of large language models, thus this statement can be inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Kỹ thuật LoRA giúp tận dụng tối đa kiến thức ban đầu từ dữ liệu lớn mà không cần phải huấn luyện lại toàn bộ mô hình.",\n            "reason": "The context explains that LoRA leverages initial knowledge without retraining the entire model, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc không cần huấn luyện lại toàn bộ mô hình không chỉ tiết kiệm thời gian mà còn giảm thiểu yêu cầu về GPU mạnh và bộ nhớ lớn.",\n            "reason": "The context supports this statement by discussing the benefits of not retraining the entire model, thus it can be inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Giảm thiểu nguy cơ quá khớp (overfitting) là một phương pháp khác.",\n            "reason": "The context mentions that reducing the number of parameters helps mitigate overfitting, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc chỉ điều chỉnh một số lượng nhỏ tham số giúp giảm nguy cơ quá khớp với dữ liệu huấn luyện.",\n          ...
# </completion>
# </generation>
#
# <generation number="3">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-CsQTV0zsPBuhvJ7aEsHT1g4w3h8QL', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "statements": [\n        {\n            "statement": "Việc điều chỉnh Adapter-tuning và kỹ thuật LoRA có thể giúp tối ưu hóa tài nguyên trong quá trình fine-tuning các mô hình ngôn ngữ lớn.",\n            "reason": "The context discusses how LoRA and PEFT techniques optimize resource usage during fine-tuning, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc điều chỉnh Adapter-tuning và kỹ thuật LoRA giúp tối ưu hóa tài nguyên thông qua các phương pháp sau.",\n            "reason": "The context mentions the optimization of resources through techniques like LoRA, but does not specify methods, making this statement not directly inferred.",\n            "verdict": 0\n        },\n        {\n            "statement": "Giảm số lượng tham số cần điều chỉnh là một trong những phương pháp.",\n            "reason": "The context states that reducing the number of parameters to adjust is a key aspect of LoRA, thus this statement can be inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Thay vì cập nhật toàn bộ các tham số của mô hình, LoRA tập trung vào việc tìm kiếm một cấu trúc có hạng thấp cho các ma trận trọng số.",\n            "reason": "The context explicitly describes LoRA\'s focus on low-rank structures instead of updating all parameters, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc tìm kiếm cấu trúc có hạng thấp giúp giảm thiểu số lượng tham số cần điều chỉnh.",\n            "reason": "The context explains that searching for low-rank structures reduces the number of parameters to adjust, thus this statement is directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Giảm thiểu số lượng tham số cần điều chỉnh giúp tiết kiệm tài nguyên.",\n            "reason": "The context implies that reducing the number of parameters leads to resource savings, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tối ưu hóa về mặt tài nguyên và thời gian là một phương pháp khác.",\n            "reason": "The context mentions optimizing resources and time as a benefit of LoRA, thus this statement can be inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Kỹ thuật LoRA cho phép huấn luyện các mô hình ngôn ngữ lớn một cách tối ưu.",\n            "reason": "The context states that LoRA allows for optimal training of large language models, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Kỹ thuật LoRA giúp tận dụng tối đa kiến thức ban đầu từ dữ liệu lớn mà không cần phải huấn luyện lại toàn bộ mô hình.",\n            "reason": "The context indicates that LoRA leverages initial knowledge without retraining the entire model, thus this statement is directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc không cần huấn luyện lại toàn bộ mô hình không chỉ tiết kiệm thời gian mà còn giảm thiểu yêu cầu về GPU mạnh và bộ nhớ lớn.",\n            "reason": "The context supports that not retraining the entire model saves time and reduces GPU and memory requirements, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Giảm thiểu nguy cơ quá khớp (overfitting) là một phương pháp khác.",\n            "reason": "The context mentions that reducing the risk of overfitting is a benefit of the techniques discussed, thus this statement can be inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc chỉ điều chỉnh một số lượng nhỏ tham số giúp giảm nguy cơ quá ...
# </completion>
# </generation>
#
# </failed_attempts>
#
# <last_exception>
#     The output is incomplete due to a max_tokens length limit.
# </last_exception>)
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluation completed in 1567.1 seconds
#   Average: 30.14s per sample
# === RAGAS SCORES ===
# {'faithfulness': 0.7845, 'answer_relevancy': 0.4954, 'context_precision': 0.8093, 'context_recall': 0.6285}

# %% [markdown]
# ### 6.4 Visualize evaluation results

# %%
results_df = ragas_results.to_pandas()
pdf_filename = "RAGAS_Evaluation_Report_API.pdf"

with PdfPages(pdf_filename) as pdf:
    sns.set_style("whitegrid")
    fig1 = plt.figure(figsize=(8, 8))

    metric_cols = [col for col in ['faithfulness', 'answer_relevancy', 'context_precision', 'context_recall']
                   if col in results_df.columns]

    if metric_cols:
        scores = {col: results_df[col].mean() for col in metric_cols}
        plt.bar(scores.keys(), scores.values(), color='skyblue', edgecolor='navy', alpha=0.7)
        plt.title(f"RAGAS Baseline Scores", fontsize=14, fontweight='bold')
        plt.ylabel("Score (0-1)")
        plt.ylim(0, 1)
        plt.legend()

    if metric_cols:
        stats_df = results_df[metric_cols].describe().round(3)
        fig2 = plt.figure(figsize=(10, 6))
        plt.axis('off')
        plt.title("Detailed Statistics", fontsize=16, fontweight='bold', pad=20)

        table = plt.table(cellText=stats_df.values,
                          colLabels=stats_df.columns,
                          rowLabels=stats_df.index,
                          loc='center',
                          cellLoc='center')
        table.auto_set_font_size(False)
        table.set_fontsize(10)
        table.scale(1.2, 1.2)

        pdf.savefig(fig2)
        plt.close(fig2)

print(f"PDF saved: {pdf_filename}")
# Out:
# /tmp/ipython-input-1392874404.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# PDF saved: RAGAS_Evaluation_Report_API.pdf

# %%
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns
import pandas as pd

# 1. Chuyển đổi kết quả Ragas sang DataFrame
# (Giả sử bạn đã có biến 'ragas_results')
results_df = ragas_results.to_pandas()

# Đặt tên cho 2 file riêng biệt
chart_filename = "RAGAS_Evaluation_Report_API_Chart.pdf"
table_filename = "RAGAS_Evaluation_Report_API_Table.pdf"

# ==========================================================
# PHẦN 1: IN CHART (FILE RIÊNG)
# ==========================================================
with PdfPages(chart_filename) as pdf:
    sns.set_style("whitegrid")
    fig1 = plt.figure(figsize=(8, 8))

    metric_cols = [col for col in ['faithfulness', 'answer_relevancy', 'context_precision', 'context_recall']
                   if col in results_df.columns]

    if metric_cols:
        scores = {col: results_df[col].mean() for col in metric_cols}

        # Vẽ biểu đồ (Giữ nguyên màu skyblue/navy như code gốc)
        plt.bar(scores.keys(), scores.values(), color='skyblue', edgecolor='navy', alpha=0.7)

        plt.title("RAGAS Baseline Scores", fontsize=14, fontweight='bold')
        plt.ylabel("Score (0-1)")
        plt.ylim(0, 1)

        # Lưu ý: plt.legend() thường không cần thiết cho biểu đồ cột đơn giản này
        # nên tôi tạm bỏ qua để tránh warning "No artists with labels found".

        # Thêm hiển thị số liệu trên cột (Optional - cho đồng bộ)
        for i, v in enumerate(scores.values()):
            plt.text(i, v + 0.01, f"{v:.2f}", ha='center', fontweight='bold')

        # Lưu biểu đồ
        pdf.savefig(fig1)

    plt.close(fig1)

print(f"✅ Đã lưu Chart vào file: {chart_filename}")

# ==========================================================
# PHẦN 2: IN TABLE (FILE RIÊNG)
# ==========================================================
with PdfPages(table_filename) as pdf:
    metric_cols = [col for col in ['faithfulness', 'answer_relevancy', 'context_precision', 'context_recall']
                   if col in results_df.columns]

    if metric_cols:
        stats_df = results_df[metric_cols].describe().round(3)
        fig2 = plt.figure(figsize=(10, 6))

        plt.axis('off')
        plt.title("Detailed Statistics", fontsize=16, fontweight='bold', pad=20)

        table = plt.table(cellText=stats_df.values,
                          colLabels=stats_df.columns,
                          rowLabels=stats_df.index,
                          loc='center',
                          cellLoc='center')

        table.auto_set_font_size(False)
        table.set_fontsize(10)
        table.scale(1.2, 1.2)

        # Lưu bảng
        pdf.savefig(fig2)
        plt.close(fig2)

print(f"✅ Đã lưu Table vào file: {table_filename}")
# Out:
# ✅ Đã lưu Chart vào file: RAGAS_Evaluation_Report_API_Chart.pdf
# ✅ Đã lưu Table vào file: RAGAS_Evaluation_Report_API_Table.pdf
