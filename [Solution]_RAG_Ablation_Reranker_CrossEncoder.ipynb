# %% [markdown]
# <a href="https://colab.research.google.com/github/VuTuanAnh0949/RAG-LangChain-Ablation-Study/blob/main/%5BSolution%5D_RAG_Ablation_Reranker_CrossEncoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Environment Setup

# %% [markdown]
# ### *1.1 Install required packages

# %%
# !pip install -q \
  "langchain>=0.2.0" \
  "langchain-core>=0.2.0" \
  "langchain-community>=0.1.0" \
  "langchain-text-splitters>=0.2.0" \
  "chromadb>=0.5.0" \
  "langchain-chroma>=0.2.0" \
  "pypdf" \
  "ragas>=0.2.0" \
  "datasets>=2.14.0" \
  "pandas" \
  "matplotlib" \
  "seaborn" \
  "openai>=1.0.0" \
  "langchain-openai>=0.1.0" \
  "gdown" \
  "tiktoken" \
  "nest_asyncio" \
  "transformers>=4.51.0" \
  "torch" \
  "accelerate"

# %% [markdown]
# ### *1.2 Import libraries

# %%
import os
import re
import json
import glob
import time
import gdown
import random
import asyncio
import unicodedata
import numpy as np
import pandas as pd
import seaborn as sns
import nest_asyncio
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

from tqdm import tqdm
from typing import List
from openai import OpenAI
from google.colab import userdata
from langchain_chroma import Chroma

from datasets import Dataset

from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

from ragas import evaluate
from ragas.run_config import RunConfig
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    context_precision,
    context_recall
)
from ragas.embeddings import LangchainEmbeddingsWrapper

nest_asyncio.apply()
# Out:
# /tmp/ipython-input-3383498540.py:37: DeprecationWarning: Importing faithfulness from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import faithfulness
#   from ragas.metrics import (
# /tmp/ipython-input-3383498540.py:37: DeprecationWarning: Importing answer_relevancy from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import answer_relevancy
#   from ragas.metrics import (
# /tmp/ipython-input-3383498540.py:37: DeprecationWarning: Importing context_precision from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_precision
#   from ragas.metrics import (
# /tmp/ipython-input-3383498540.py:37: DeprecationWarning: Importing context_recall from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_recall
#   from ragas.metrics import (

# %% [markdown]
# ### 1.3 Set global seed for reproducibility (SEED = 42)

# %%
SEED = 42

def set_global_seed(seed_value: int = 42):
    random.seed(seed_value)
    np.random.seed(seed_value)
    os.environ['PYTHONHASHSEED'] = str(seed_value)
    print(f"Global seed set to {seed_value}")

set_global_seed(SEED)
# Out:
# Global seed set to 42

# %% [markdown]
# ### 1.4 Configure API Keys

# %%
os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")
OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]

print("OpenAI API Key configured successfully")
# Out:
# OpenAI API Key configured successfully

# %% [markdown]
# ### *1.5 Batch Processing Configuration

# %%
BATCH_SIZE = 32
EMBEDDING_BATCH_SIZE = 100

LLM_MODEL = "gpt-4o-mini"
EMBEDDING_MODEL = "text-embedding-3-small"

RERANKER_MODEL = "Qwen/Qwen3-Reranker-0.6B"
RETRIEVE_K = 10  # Retrieve more docs before reranking
RERANK_TOP_K = 3  # Keep top K after reranking

EVAL_SAMPLE_SIZE = None
EVAL_MAX_WORKERS = 64
EVAL_TIMEOUT = 180

print(f"Configuration:")
print(f"  - LLM Model: {LLM_MODEL}")
print(f"  - Embedding Model: {EMBEDDING_MODEL}")
print(f"  - Reranker Model: {RERANKER_MODEL}")
print(f"  - Retrieve K: {RETRIEVE_K} -> Rerank Top K: {RERANK_TOP_K}")
print(f"  - Batch Size: {BATCH_SIZE}")
print(f"  - RAGAS Eval Workers: {EVAL_MAX_WORKERS}")
print(f"  - Eval Sample Size: {'ALL' if EVAL_SAMPLE_SIZE is None else EVAL_SAMPLE_SIZE}")
# Out:
# Configuration:
#   - LLM Model: gpt-4o-mini
#   - Embedding Model: text-embedding-3-small
#   - Reranker Model: Qwen/Qwen3-Reranker-0.6B
#   - Retrieve K: 10 -> Rerank Top K: 3
#   - Batch Size: 32
#   - RAGAS Eval Workers: 64
#   - Eval Sample Size: ALL

# %% [markdown]
# ## 2. Data Preparation

# %% [markdown]
# ### 2.1 Download data

# %%
# !gdown 1Ebcv-0kq6_eF6QYfIMSL6ZXQUnETnWKW
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Ebcv-0kq6_eF6QYfIMSL6ZXQUnETnWKW
# From (redirected): https://drive.google.com/uc?id=1Ebcv-0kq6_eF6QYfIMSL6ZXQUnETnWKW&confirm=t&uuid=35e580ed-b647-486c-89a8-c012aea94d45
# To: /content/RAG_DATA.zip
# 100% 133M/133M [00:02<00:00, 46.0MB/s]

# %%
file_id = "1Ebcv-0kq6_eF6QYfIMSL6ZXQUnETnWKW"
zip_path = "/content/data.zip"
gdown.download(f"https://drive.google.com/uc?id={file_id}", zip_path, quiet=False)

# !unzip -o /content/data.zip
DATA_DIR = "RAG_DATA"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Ebcv-0kq6_eF6QYfIMSL6ZXQUnETnWKW
# From (redirected): https://drive.google.com/uc?id=1Ebcv-0kq6_eF6QYfIMSL6ZXQUnETnWKW&confirm=t&uuid=0ddb0ed1-ff50-41bd-a23d-edbc07754e10
# To: /content/data.zip
# 100%|██████████| 133M/133M [00:01<00:00, 127MB/s]
# Archive:  /content/data.zip
#    creating: RAG_DATA/
#   inflating: RAG_DATA/AI_Agents_Smolagents.pdf
#   inflating: RAG_DATA/AI_Image_Gen_Edit_CFM.pdf
#   inflating: RAG_DATA/AI_Linear_Algebra_NumPy_Practice.pdf
#   inflating: RAG_DATA/AI_Multi_Agent_Supervisor.pdf
#   inflating: RAG_DATA/AI_Problem_Solving.pdf
#   inflating: RAG_DATA/AI_Problem_Solving_Framework.pdf
#   inflating: RAG_DATA/AI_Vietnamese_Poetry.pdf
#   inflating: RAG_DATA/Applied_Statistics_AI.pdf
#   inflating: RAG_DATA/CNN_Exercise.pdf
#   inflating: RAG_DATA/Effective_Data_Presentation.pdf
#   inflating: RAG_DATA/Emoji_Generation_Stable_Diffusion.pdf
#   inflating: RAG_DATA/Git_DS_Roadmap.pdf
#   inflating: RAG_DATA/Hand_Gesture_Control_System_Tutorial.pdf
#   inflating: RAG_DATA/Interpolation_Missing_Data.pdf
#   inflating: RAG_DATA/LangChain_RAG_PDF_QA_Guide.pdf
#   inflating: RAG_DATA/LLM_Alignment_DPO.pdf
#   inflating: RAG_DATA/LLM_IT_SAT_Reading.pdf
#   inflating: RAG_DATA/LLM_Math_Reasoning_GRPO.pdf
#   inflating: RAG_DATA/LoRA_QLoRA_LLM_Tutorial.pdf
#   inflating: RAG_DATA/MiniGPT4V_Fine_Tuning_Tutorial.pdf
#   inflating: RAG_DATA/MT_Low_Resource_Fine_tuning.pdf
#   inflating: RAG_DATA/Naive_Bayes_Classification_Exercise.pdf
#   inflating: RAG_DATA/Naive_Bayes_Classifiers.pdf
#   inflating: RAG_DATA/NLP_Text_Classification.pdf
#   inflating: RAG_DATA/OOP_DS_Exercises.pdf
#   inflating: RAG_DATA/OOP_Guide.pdf
#   inflating: RAG_DATA/PDF_QA_RAG_LLM.pdf
#   inflating: RAG_DATA/PEFT_LLM_MCQA.pdf
#   inflating: RAG_DATA/Python_AI_ML.pdf
#   inflating: RAG_DATA/Python_Basics_Quiz.pdf
#   inflating: RAG_DATA/Python_Dictionary_NLP_AI.pdf
#   inflating: RAG_DATA/Python_DS_Best_Practices.pdf
#   inflating: RAG_DATA/Python_List_AI_ML_Lab.pdf
#   inflating: RAG_DATA/Python_Naming_Conventions.pdf
#   inflating: RAG_DATA/Python_OOP_Best_Practices.pdf
#   inflating: RAG_DATA/Python_OOP_Errors.pdf
#   inflating: RAG_DATA/Python_Variables_Memory.pdf
#   inflating: RAG_DATA/Python_Word_Cloud.pdf
#   inflating: RAG_DATA/ReAct_Plan_Execute_LangGraph.pdf
#   inflating: RAG_DATA/Spam_Classification_Project.pdf
#   inflating: RAG_DATA/Streamlit_Student_Scores_Analysis.pdf
#   inflating: RAG_DATA/Streamlit_Web_App_Guide.pdf
#   inflating: RAG_DATA/Tool_Calling_LLM_Intro.pdf
#   inflating: RAG_DATA/Typo_Correction_QWERTY.pdf
#   inflating: RAG_DATA/Vietnamese_Chatbot_RLHF.pdf

# %% [markdown]
# ### 2.2 Download testing file

# %%
file_id = "1a5RL7ex88w_5tZ1g6R31QTrfibvxqT_Q"
gdown.download(f"https://drive.google.com/uc?id={file_id}", quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1a5RL7ex88w_5tZ1g6R31QTrfibvxqT_Q
# To: /content/testset.json
# 100%|██████████| 312k/312k [00:00<00:00, 4.73MB/s]
# 'testset.json'

# %% [markdown]
# ## 3. Model Configuration (API-based)

# %%
def get_llm(
    model_name: str = LLM_MODEL,
    temperature: float = 0.0,
    max_tokens: int = 8192,
    seed: int = SEED,
):
    llm = ChatOpenAI(
        model=model_name,
        temperature=temperature,
        max_tokens=max_tokens,
        seed=seed,
        api_key=OPENAI_API_KEY,
    )
    print(f"LLM initialized: {model_name} (seed={seed})")
    return llm


def get_embeddings(
    model_name: str = EMBEDDING_MODEL,
    chunk_size: int = EMBEDDING_BATCH_SIZE,
):
    embeddings = OpenAIEmbeddings(
        model=model_name,
        api_key=OPENAI_API_KEY,
        chunk_size=chunk_size,
    )
    print(f"Embeddings initialized: {model_name} (batch_size={chunk_size})")
    return embeddings

# %% [markdown]
# ## 4. RAG Components

# %% [markdown]
# ### 4.1 Define Vietnamese text cleaning function

# %%
def clean_vietnamese_text(text: str) -> str:
    text = unicodedata.normalize('NFC', text)
    text = "".join(
        char for char in text
        if not unicodedata.category(char).startswith('C') or char in '\n\t'
    )
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'\n\s*\n', '\n', text)
    return text.strip()

# %% [markdown]
# ### 4.2 Define document loader and text splitter

# %%
class SimpleLoader:
    def load_pdf(self, pdf_file: str):
        docs = PyPDFLoader(pdf_file, extract_images=True).load()
        for doc in docs:
            doc.page_content = clean_vietnamese_text(doc.page_content)
        return docs

    def load_dir(self, dir_path: str) -> List:
        pdf_files = glob.glob(f"{dir_path}/*.pdf")
        if not pdf_files:
            raise ValueError(f"No PDF files found in {dir_path}")

        all_docs = []
        for pdf_file in tqdm(pdf_files, desc="Loading PDFs"):
            try:
                all_docs.extend(self.load_pdf(pdf_file))
            except Exception as e:
                pass
        return all_docs


class TextSplitter:
    def __init__(
        self,
        chunk_size: int = 1024,
        chunk_overlap: int = 128,
    ):
        self.splitter = RecursiveCharacterTextSplitter(
            separators=["\n\n", "\n", " ", ""],
            chunk_size=chunk_size,
            chunk_overlap=chunk_overlap,
            length_function=len,
        )

    def split(self, documents):
        return self.splitter.split_documents(documents)

# %% [markdown]
# ### *4.3 Define vector database class (API Embeddings)

# %%
class VectorDB:
    def __init__(
        self,
        documents=None,
        embedding=None,
        collection_name: str = "vietnamese_docs",
        persist_dir: str = "/content/chroma_data",
    ):
        self.persist_dir = persist_dir
        self.collection_name = collection_name
        self.embedding = embedding or get_embeddings()
        self.db = self._build_db(documents)

    def _build_db(self, documents):
        if documents is None or len(documents) == 0:
            db = Chroma(
                collection_name=self.collection_name,
                embedding_function=self.embedding,
                persist_directory=self.persist_dir,
            )
        else:
            print(f"Building vector database with {len(documents)} documents...")
            db = Chroma.from_documents(
                documents=documents,
                embedding=self.embedding,
                collection_name=self.collection_name,
                persist_directory=self.persist_dir,
            )
            print(f"Vector database built successfully!")
        return db

    def get_retriever(self, search_kwargs: dict = None):
        # Retrieve more documents for reranking
        if search_kwargs is None:
            search_kwargs = {"k": RETRIEVE_K}

        return self.db.as_retriever(
            search_type="similarity",
            search_kwargs=search_kwargs,
        )

# %% [markdown]
# ### *4.4 Define Cross-Encoder Reranker (Qwen3-Reranker)

# %%
class CrossEncoderReranker:
    """Cross-Encoder Reranker using Qwen3-Reranker model."""

    def __init__(self, model_name: str = RERANKER_MODEL, top_k: int = RERANK_TOP_K):
        self.top_k = top_k
        self.model_name = model_name

        print(f"Loading Cross-Encoder Reranker: {model_name}...")
        self.tokenizer = AutoTokenizer.from_pretrained(model_name, padding_side='left')
        self.model = AutoModelForCausalLM.from_pretrained(
            model_name,
            torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32
        ).eval()

        if torch.cuda.is_available():
            self.model = self.model.cuda()
            print(f"Reranker loaded on GPU")
        else:
            print(f"Reranker loaded on CPU")

        # Token IDs for scoring
        self.token_false_id = self.tokenizer.convert_tokens_to_ids("no")
        self.token_true_id = self.tokenizer.convert_tokens_to_ids("yes")
        self.max_length = 8192

        # Prompt templates
        self.prefix = "<|im_start|>system\nJudge whether the Document meets the requirements based on the Query and the Instruct provided. Note that the answer can only be \"yes\" or \"no\".<|im_end|>\n<|im_start|>user\n"
        self.suffix = "<|im_end|>\n<|im_start|>assistant\n<think>\n\n</think>\n\n"
        self.prefix_tokens = self.tokenizer.encode(self.prefix, add_special_tokens=False)
        self.suffix_tokens = self.tokenizer.encode(self.suffix, add_special_tokens=False)

    def _format_instruction(self, query: str, doc: str) -> str:
        instruction = 'Given a web search query, retrieve relevant passages that answer the query'
        return f"<Instruct>: {instruction}\n<Query>: {query}\n<Document>: {doc}"

    def _process_inputs(self, pairs: List[str]):
        inputs = self.tokenizer(
            pairs,
            padding=False,
            truncation='longest_first',
            return_attention_mask=False,
            max_length=self.max_length - len(self.prefix_tokens) - len(self.suffix_tokens)
        )
        for i, ele in enumerate(inputs['input_ids']):
            inputs['input_ids'][i] = self.prefix_tokens + ele + self.suffix_tokens
        inputs = self.tokenizer.pad(inputs, padding=True, return_tensors="pt", max_length=self.max_length)
        for key in inputs:
            inputs[key] = inputs[key].to(self.model.device)
        return inputs

    @torch.no_grad()
    def _compute_scores(self, inputs) -> List[float]:
        batch_scores = self.model(**inputs).logits[:, -1, :]
        true_vector = batch_scores[:, self.token_true_id]
        false_vector = batch_scores[:, self.token_false_id]
        batch_scores = torch.stack([false_vector, true_vector], dim=1)
        batch_scores = torch.nn.functional.log_softmax(batch_scores, dim=1)
        scores = batch_scores[:, 1].exp().tolist()
        return scores

    def rerank(self, query: str, documents: List) -> List:
        """Rerank documents based on query relevance."""
        if len(documents) == 0:
            return documents

        # Create query-document pairs
        pairs = [self._format_instruction(query, doc.page_content) for doc in documents]

        # Compute scores
        inputs = self._process_inputs(pairs)
        scores = self._compute_scores(inputs)

        # Sort by score and return top_k
        doc_score_pairs = list(zip(documents, scores))
        doc_score_pairs.sort(key=lambda x: x[1], reverse=True)

        return [doc for doc, score in doc_score_pairs[:self.top_k]]

# %% [markdown]
# ### *4.5 Define RAG pipeline with batch processing and reranking

# %%
class FocusedAnswerParser(StrOutputParser):
    def parse(self, text: str) -> str:
        text = (text or "").strip()
        if "[TRẢ LỜI]:" in text:
            answer = text.split("[TRẢ LỜI]:")[-1].strip()
        else:
            answer = text

        answer = re.sub(r'^\s*[•\-\*]\s*', '', answer, flags=re.MULTILINE)
        answer = re.sub(r'\n+', ' ', answer).strip()
        return answer


class BatchRAG:
    def __init__(self, llm, reranker=None, batch_size: int = BATCH_SIZE):
        self.llm = llm
        self.reranker = reranker  # Cross-Encoder Reranker
        self.batch_size = batch_size
        self.prompt_template = """Bạn là trợ lý AI phân tích tài liệu tiếng Việt.

[TÀI LIỆU]:
{context}

[CÂU HỎI]:
{question}

Hãy trả lời dựa trên tài liệu. Nếu tài liệu không có thông tin, nói rõ "Không có thông tin".
[TRẢ LỜI]:"""
        self.prompt = PromptTemplate.from_template(self.prompt_template)
        self.answer_parser = FocusedAnswerParser()

    def _format_docs(self, docs):
        formatted = []
        seen = set()
        for doc in docs:
            content = (doc.page_content or "").strip()
            if content and len(content) > 40 and content not in seen:
                formatted.append(content)
                seen.add(content)
        return "\n\n".join(formatted)

    def get_chain(self, retriever):
        def format_docs(docs):
            return self._format_docs(docs)

        rag_chain = (
            {"context": retriever | format_docs, "question": RunnablePassthrough()}
            | self.prompt
            | self.llm
            | self.answer_parser
        )
        return rag_chain

    def batch_retrieve(self, questions: List[str], retriever) -> List[dict]:
        all_contexts = []
        for question in tqdm(questions, desc="Retrieving and reranking documents"):
            docs = retriever.invoke(question)

            # Apply Cross-Encoder Reranking
            if self.reranker is not None:
                docs = self.reranker.rerank(question, docs)

            contexts = [(doc.page_content or "") for doc in docs]
            formatted_context = self._format_docs(docs)
            all_contexts.append({
                "question": question,
                "contexts": contexts,
                "formatted_context": formatted_context
            })
        return all_contexts

    def batch_generate(self, prompts: List[str]) -> List[str]:
        from langchain_core.messages import HumanMessage

        all_answers = []
        for i in tqdm(range(0, len(prompts), self.batch_size), desc="Generating answers"):
            batch = prompts[i:i + self.batch_size]

            messages_batch = [[HumanMessage(content=p)] for p in batch]
            batch_results = self.llm.batch(messages_batch)

            for result in batch_results:
                answer = self.answer_parser.parse(result.content)
                all_answers.append(answer)

        return all_answers

    def answer_with_contexts_batch(self, questions: List[str], retriever):
        print(f"Processing {len(questions)} questions in batches of {self.batch_size}...")
        print(f"Using Cross-Encoder Reranker: {self.reranker is not None}")
        retrieved_data = self.batch_retrieve(questions, retriever)
        prompts = [
            self.prompt.format(
                context=data["formatted_context"],
                question=data["question"]
            )
            for data in retrieved_data
        ]
        answers = self.batch_generate(prompts)

        results = []
        for data, answer in zip(retrieved_data, answers):
            results.append({
                "answer": answer,
                "contexts": data["contexts"]
            })

        return results

# %% [markdown]
# ## *5. RAG System Initialization

# %%
set_global_seed(SEED)

llm = get_llm(model_name=LLM_MODEL, seed=SEED)
embeddings = get_embeddings(model_name=EMBEDDING_MODEL, chunk_size=EMBEDDING_BATCH_SIZE)

# Initialize Cross-Encoder Reranker
reranker = CrossEncoderReranker(model_name=RERANKER_MODEL, top_k=RERANK_TOP_K)

loader = SimpleLoader()
text_splitter = TextSplitter(chunk_size=1024, chunk_overlap=128)

raw_docs = loader.load_dir(DATA_DIR)
split_docs = text_splitter.split(raw_docs)
print(f"Total documents: {len(raw_docs)}, Split chunks: {len(split_docs)}")

vdb = VectorDB(documents=split_docs, embedding=embeddings)
retriever = vdb.get_retriever(search_kwargs={"k": RETRIEVE_K})

# Initialize RAG with reranker
rag = BatchRAG(llm, reranker=reranker, batch_size=BATCH_SIZE)
rag_chain = rag.get_chain(retriever)

print("\n" + "="*50)
print("RAG System initialized successfully!")
print(f"  - LLM: {LLM_MODEL} (API)")
print(f"  - Embeddings: {EMBEDDING_MODEL} (API)")
print(f"  - Reranker: {RERANKER_MODEL}")
print(f"  - Retrieve K: {RETRIEVE_K} -> Rerank Top K: {RERANK_TOP_K}")
print(f"  - Batch Size: {BATCH_SIZE}")
print(f"  - Seed: {SEED}")
print("="*50)
# Out:
# Global seed set to 42
# LLM initialized: gpt-4o-mini (seed=42)
# Embeddings initialized: text-embedding-3-small (batch_size=100)
# Loading Cross-Encoder Reranker: Qwen/Qwen3-Reranker-0.6B...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/1.19G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/214 [00:00<?, ?B/s]
# Reranker loaded on GPU
# Loading PDFs:  60%|██████    | 27/45 [00:42<00:17,  1.00it/s]WARNING:pypdf._reader:Ignoring wrong pointing object 7 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 9 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 17 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 25 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 27 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 29 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 31 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 40 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 42 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 49 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 51 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 53 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 55 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 57 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 68 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 70 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 77 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 79 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 117 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 129 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 143 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 152 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 155 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 243 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 307 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 354 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 399 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 401 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 417 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 419 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 423 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 430 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 433 0 (offset 0)
# Loading PDFs:  64%|██████▍   | 29/45 [00:44<00:16,  1.05s/it]WARNING:pypdf._reader:Ignoring wrong pointing object 8 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 10 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 21 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 23 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 25 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 27 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 29 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 31 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 33 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 35 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 37 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 49 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 52 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 54 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 67 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 82 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 85 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 104 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 132 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 160 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 162 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 196 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 203 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 205 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 215 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 241 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 268 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 296 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 306 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 345 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 388 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 410 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 430 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 457 0 (offset 0)
# Loading PDFs: 100%|██████████| 45/45 [01:04<00:00,  1.44s/it]
# Total documents: 1372, Split chunks: 2184
# Building vector database with 2184 documents...
# Vector database built successfully!
#
# ==================================================
# RAG System initialized successfully!
#   - LLM: gpt-4o-mini (API)
#   - Embeddings: text-embedding-3-small (API)
#   - Reranker: Qwen/Qwen3-Reranker-0.6B
#   - Retrieve K: 10 -> Rerank Top K: 3
#   - Batch Size: 32
#   - Seed: 42
# ==================================================

# %% [markdown]
# ## 6. Evaluation

# %% [markdown]
# ### 6.1 Load testing data from JSON

# %%
testset_path = 'testset.json'

with open(testset_path, 'r', encoding='utf-8') as f:
    testset_data = json.load(f)

test_df = pd.DataFrame([
    {
        'user_input': item['user_input'],
        'reference': item['reference'],
        'reference_contexts': item['reference_contexts']
    }
    for item in testset_data
])

print(f"Loaded {len(test_df)} test questions from testset.json")
display(test_df.head())
# Out:
# Loaded 52 test questions from testset.json
#                                           user_input  \
# 0  Máy học là gì và nó có vai trò gì trong phân l...
# 1  Cơ sở dữ liệu Vector là gì và nó được sử dụng ...
# 2  What is the significance of the FA Cup in the ...
# 3  What libraries are commonly used in AI VIET NA...
# 4  What are the key steps involved in the data pr...
#
#                                            reference  \
# 0  Máy học là một lĩnh vực phổ biến trong phân lo...
# 1  Cơ sở dữ liệu Vector được sử dụng trong việc x...
# 2  The FA Cup is mentioned in a spam message that...
# 3  In AI VIET NAM, commonly used libraries for na...
# 4  The key steps involved in the data preprocessi...
#
#                                   reference_contexts
# 0  [I. Giới thiệu** **Text Classification (Tạm dị...
# 1  [II.2. Cài đặt và Import thư viện . . . . . . ...
# 2  [. . . . . . . . . . . . . . . . . . . 14 III....
# 3  [Text FA to 87121 to receive entr...| |spam|Fr...
# 4  [phần đặc trưng và nhãn, sau khi có dataframe,...

# %% [markdown]
# ### 6.2 Run batch predictions on test questions (API)

# %%
set_global_seed(SEED)

print(f"LLM: {LLM_MODEL}")
print(f"Reranker: {RERANKER_MODEL}")
print(f"Batch size: {BATCH_SIZE}")

questions = test_df['user_input'].tolist()

start_time = time.time()
batch_results = rag.answer_with_contexts_batch(questions, retriever)
elapsed_time = time.time() - start_time

print(f"Inference completed in {elapsed_time:.2f} seconds")
print(f"Average time per question: {elapsed_time/len(questions):.2f} seconds")

results = []
for idx, (result, (_, row)) in enumerate(zip(batch_results, test_df.iterrows())):
    results.append({
        "user_input": row['user_input'],
        "response": result["answer"],
        "retrieved_contexts": result["contexts"],
        "reference": row.get('reference', ''),
        "reference_contexts": row.get('reference_contexts', [])
    })

eval_df = pd.DataFrame(results)
print(f"Collected {len(eval_df)} predictions")
display(eval_df.head())
# Out:
# Global seed set to 42
# LLM: gpt-4o-mini
# Reranker: Qwen/Qwen3-Reranker-0.6B
# Batch size: 32
# Processing 52 questions in batches of 32...
# Using Cross-Encoder Reranker: True
# Retrieving and reranking documents:   0%|          | 0/52 [00:00<?, ?it/s]You're using a Qwen2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:2914: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# Retrieving and reranking documents: 100%|██████████| 52/52 [00:40<00:00,  1.29it/s]
# Generating answers: 100%|██████████| 2/2 [00:44<00:00, 22.17s/it]
# Inference completed in 84.72 seconds
# Average time per question: 1.63 seconds
# Collected 52 predictions
#                                           user_input  \
# 0  Máy học là gì và nó có vai trò gì trong phân l...
# 1  Cơ sở dữ liệu Vector là gì và nó được sử dụng ...
# 2  What is the significance of the FA Cup in the ...
# 3  What libraries are commonly used in AI VIET NA...
# 4  What are the key steps involved in the data pr...
#
#                                             response  \
# 0  Máy học (Machine Learning) là một lĩnh vực tro...
# 1  Cơ sở dữ liệu Vector là một phương pháp lưu tr...
# 2                                Không có thông tin.
# 3  Các thư viện thường được sử dụng trong AI VIET...
# 4  Các bước chính trong quá trình tiền xử lý dữ l...
#
#                                   retrieved_contexts  \
# 0  [AI VIET NAM (AIO2025) aivietnam.edu.vn 5. Rub...
# 1  [AI VIET NAM (AIO2025) aivietnam.edu.vn III. X...
# 2  [AI VIET NAM (AIO2025) aivietnam.edu.vn II. Xâ...
# 3  [AI VIET NAM (AIO2025) aivietnam.edu.vn • stri...
# 4  [AI VIETNAM (AIO2024) aivietnam.edu.vn • Crawl...
#
#                                            reference  \
# 0  Máy học là một lĩnh vực phổ biến trong phân lo...
# 1  Cơ sở dữ liệu Vector được sử dụng trong việc x...
# 2  The FA Cup is mentioned in a spam message that...
# 3  In AI VIET NAM, commonly used libraries for na...
# 4  The key steps involved in the data preprocessi...
#
#                                   reference_contexts
# 0  [I. Giới thiệu** **Text Classification (Tạm dị...
# 1  [II.2. Cài đặt và Import thư viện . . . . . . ...
# 2  [. . . . . . . . . . . . . . . . . . . 14 III....
# 3  [Text FA to 87121 to receive entr...| |spam|Fr...
# 4  [phần đặc trưng và nhãn, sau khi có dataframe,...

# %% [markdown]
# ### 6.3 Evaluate RAG with RAGAS metrics (⚡ Optimized for Speed)

# %%
if EVAL_SAMPLE_SIZE is not None:
    eval_subset = eval_df.sample(n=min(EVAL_SAMPLE_SIZE, len(eval_df)), random_state=SEED)
    print(f"Quick evaluation mode: Using {len(eval_subset)} samples")
else:
    eval_subset = eval_df
    print(f"Full evaluation: Using all {len(eval_subset)} samples")

eval_dataset = Dataset.from_pandas(eval_subset.reset_index(drop=True))

wrapped_embeddings = LangchainEmbeddingsWrapper(
    OpenAIEmbeddings(model='text-embedding-3-small')
)

run_config = RunConfig(
    max_workers=EVAL_MAX_WORKERS,
    timeout=EVAL_TIMEOUT,
    max_retries=1,
    max_wait=60,
)

print(f"Running RAGAS evaluation...")
print(f"   - Parallel workers: {EVAL_MAX_WORKERS}")
print(f"   - Samples: {len(eval_subset)}")

start_time = time.time()

ragas_results = evaluate(
    dataset=eval_dataset,
    metrics=[
        faithfulness,
        answer_relevancy,
        context_precision,
        context_recall
    ],
    embeddings=wrapped_embeddings,
    run_config=run_config,
    raise_exceptions=False,
)

eval_time = time.time() - start_time
print(f"\nEvaluation completed in {eval_time:.1f} seconds")
print(f"  Average: {eval_time/len(eval_subset):.2f}s per sample")

print("=" * 50)
print("=== RAGAS SCORES (Cross-Encoder Reranking) ===")
print("=" * 50)
print(ragas_results)
# Out:
# /tmp/ipython-input-1260192757.py:10: DeprecationWarning: LangchainEmbeddingsWrapper is deprecated and will be removed in a future version. Use the modern embedding providers instead: embedding_factory('openai', model='text-embedding-3-small', client=openai_client) or from ragas.embeddings import OpenAIEmbeddings, GoogleEmbeddings, HuggingFaceEmbeddings
#   wrapped_embeddings = LangchainEmbeddingsWrapper(
# Full evaluation: Using all 52 samples
# Running RAGAS evaluation...
#    - Parallel workers: 64
#    - Samples: 52
# Evaluating:   0%|          | 0/208 [00:00<?, ?it/s]
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# ERROR:ragas.executor:Exception raised in Job[80]: InstructorRetryException(<failed_attempts>
#
# <generation number="1">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-CsZERKdpxb4qmG8IOqiSdh1XLvnuh', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "statements": [\n        {\n            "statement": "Để xác định đúng vấn đề trong dự án AI, cần thực hiện các bước sau.",\n            "reason": "The context discusses the importance of correctly identifying the problem in AI projects but does not specify the steps to do so.",\n            "verdict": 0\n        },\n        {\n            "statement": "Bắt đầu từ vấn đề kinh doanh cụ thể là bước đầu tiên.",\n            "reason": "The context mentions starting from a specific business problem but does not explicitly state that it is the first step.",\n            "verdict": 0\n        },\n        {\n            "statement": "Thay vì chỉ tập trung vào triệu chứng, cần xác định rõ ràng vấn đề gốc rễ mà dự án muốn giải quyết.",\n            "reason": "The context emphasizes the need to focus on root causes rather than symptoms, which supports this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Phân tích tìm nguyên nhân gốc rễ là bước thứ hai.",\n            "reason": "The context mentions analyzing to find root causes but does not specify it as the second step.",\n            "verdict": 0\n        },\n        {\n            "statement": "Phân tích tìm nguyên nhân gốc rễ giúp hiểu rõ hơn về bản chất của vấn đề.",\n            "reason": "The context implies that analyzing root causes helps understand the nature of the problem, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Phân tích tìm nguyên nhân gốc rễ tránh việc giải quyết những vấn đề không thực sự quan trọng.",\n            "reason": "The context suggests that analyzing root causes prevents addressing unimportant issues, which aligns with this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Áp dụng tiêu chí SMART là bước thứ ba.",\n            "reason": "The context mentions applying SMART criteria but does not specify it as the third step.",\n            "verdict": 0\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa một cách cụ thể.",\n            "reason": "The context states that SMART criteria ensure specific problem definitions, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa là đo lường được.",\n            "reason": "The context indicates that SMART criteria ensure the problem is measurable, which supports this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa có thể đạt được.",\n            "reason": "The context mentions that SMART criteria ensure the problem is achievable, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa là thực tế.",\n            "reason": "The context states that SMART criteria ensure the problem is realistic, which supports this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa có thời hạn rõ ràng.",\n            "reason": "The context indicates that SMART criteria ensure the problem has a clear timeframe, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Xác định rõ KPI đo lường là bước thứ tư.",\n            "reason": "The context mentions establishing clear KPIs but does not specify it as the fourth step.",\n            "verdict": 0\n        },\n        {\n            "statement": "Thiết lập các chỉ số hiệu suất chính (KPIs) phù hợp để đánh giá hiệu quả của giải pháp AI là cần thiết.",\n            "reason": "The context states that establish ...
# </completion>
# </generation>
#
# <generation number="2">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-CsZEhd4BBqdXuG8Zx8hE70vasFGOp', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "statements": [\n        {\n            "statement": "Để xác định đúng vấn đề trong dự án AI, cần thực hiện các bước sau.",\n            "reason": "The context discusses the importance of correctly identifying the problem in AI projects, implying that there are steps involved, but it does not explicitly list them.",\n            "verdict": 0\n        },\n        {\n            "statement": "Bắt đầu từ vấn đề kinh doanh cụ thể là bước đầu tiên.",\n            "reason": "The context mentions starting from a specific business problem as part of the process, but does not explicitly state it as the first step.",\n            "verdict": 0\n        },\n        {\n            "statement": "Thay vì chỉ tập trung vào triệu chứng, cần xác định rõ ràng vấn đề gốc rễ mà dự án muốn giải quyết.",\n            "reason": "The context emphasizes the need to focus on root causes rather than symptoms, which supports this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Phân tích tìm nguyên nhân gốc rễ là bước thứ hai.",\n            "reason": "The context mentions analyzing to find root causes but does not specify it as the second step.",\n            "verdict": 0\n        },\n        {\n            "statement": "Phân tích tìm nguyên nhân gốc rễ giúp hiểu rõ hơn về bản chất của vấn đề.",\n            "reason": "The context implies that analyzing root causes aids in understanding the problem better, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Phân tích tìm nguyên nhân gốc rễ tránh việc giải quyết những vấn đề không thực sự quan trọng.",\n            "reason": "The context suggests that analyzing root causes helps avoid addressing unimportant issues, which aligns with this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Áp dụng tiêu chí SMART là bước thứ ba.",\n            "reason": "The context mentions applying SMART criteria but does not specify it as the third step.",\n            "verdict": 0\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa một cách cụ thể.",\n            "reason": "The context states that SMART criteria ensure specific definitions of problems, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa là đo lường được.",\n            "reason": "The context indicates that SMART criteria ensure that problems are measurable, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa có thể đạt được.",\n            "reason": "The context mentions that SMART criteria ensure that problems are achievable, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa là thực tế.",\n            "reason": "The context states that SMART criteria ensure that problems are realistic, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa có thời hạn rõ ràng.",\n            "reason": "The context indicates that SMART criteria ensure that problems have clear deadlines, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Xác định rõ KPI đo lường là bước thứ tư.",\n            "reason": "The context mentions establishing clear KPIs but does not specify it as the fourth step.",\n            "verdict": 0\n        },\n        {\n            "statement": "Thiết lập các chỉ số hiệu suất chính (KPIs) phù hợp để đánh giá hiệu quả của giải pháp AI là cần th ...
# </completion>
# </generation>
#
# <generation number="3">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-CsZF1r0v71cg060misXlte9N3twNA', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "statements": [\n        {\n            "statement": "Để xác định đúng vấn đề trong dự án AI, cần thực hiện các bước sau.",\n            "reason": "The context discusses the importance of correctly identifying the problem in AI projects, implying that there are steps involved, but does not specify what those steps are.",\n            "verdict": 0\n        },\n        {\n            "statement": "Bắt đầu từ vấn đề kinh doanh cụ thể là bước đầu tiên.",\n            "reason": "The context mentions starting from a specific business problem as part of the process, indicating that this is indeed a step to take.",\n            "verdict": 1\n        },\n        {\n            "statement": "Thay vì chỉ tập trung vào triệu chứng, cần xác định rõ ràng vấn đề gốc rễ mà dự án muốn giải quyết.",\n            "reason": "The context emphasizes the need to focus on the root cause rather than just symptoms, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Phân tích tìm nguyên nhân gốc rễ là bước thứ hai.",\n            "reason": "The context suggests that analyzing to find the root cause is an important step, but does not explicitly state it as the second step.",\n            "verdict": 0\n        },\n        {\n            "statement": "Phân tích tìm nguyên nhân gốc rễ giúp hiểu rõ hơn về bản chất của vấn đề.",\n            "reason": "The context implies that analyzing the root cause aids in understanding the nature of the problem, thus supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Phân tích tìm nguyên nhân gốc rễ tránh việc giải quyết những vấn đề không thực sự quan trọng.",\n            "reason": "The context suggests that identifying the correct problem helps avoid addressing less important issues, which aligns with this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Áp dụng tiêu chí SMART là bước thứ ba.",\n            "reason": "The context mentions applying SMART criteria but does not specify it as the third step.",\n            "verdict": 0\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa một cách cụ thể.",\n            "reason": "The context states that SMART criteria ensure that the problem is defined specifically, thus supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa là đo lường được.",\n            "reason": "The context indicates that SMART criteria ensure the problem is measurable, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa có thể đạt được.",\n            "reason": "The context supports that SMART criteria ensure the problem is achievable, thus this statement is valid.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa là thực tế.",\n            "reason": "The context implies that SMART criteria ensure the problem is realistic, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiêu chí SMART đảm bảo rằng vấn đề được định nghĩa có thời hạn rõ ràng.",\n            "reason": "The context states that SMART criteria ensure the problem has a clear timeframe, thus supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Xác định rõ KPI đo lường là bước thứ tư.",\n            "reason": "The context mentions establishing clear KPIs but does not specify it as the fourth step.",\n            "verdict": 0\n        },\n        {\n            "statement": "Thiết lập các chỉ s ...
# </completion>
# </generation>
#
# </failed_attempts>
#
# <last_exception>
#     The output is incomplete due to a max_tokens length limit.
# </last_exception>)
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# ERROR:ragas.executor:Exception raised in Job[84]: InstructorRetryException(<failed_attempts>
#
# <generation number="1">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-CsZFksQAv6lmTwIQWZrWCLQpq3FY3', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "statements": [\n        {\n            "statement": "Tư duy logic và kỹ năng giải quyết vấn đề quan trọng cho việc tối ưu hóa nguồn lực và tăng doanh thu trong các dự án AI.",\n            "reason": "The context emphasizes the importance of logical thinking and problem-solving skills in optimizing resources, but it does not explicitly mention increasing revenue in AI projects.",\n            "verdict": 0\n        },\n        {\n            "statement": "Tư duy logic giúp xác định chính xác vấn đề cần giải quyết.",\n            "reason": "The context states that logical thinking helps identify the right problems, which directly supports this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc xác định đúng vấn đề đảm bảo rằng các giải pháp được phát triển sẽ mang lại giá trị thực sự cho doanh nghiệp.",\n            "reason": "The context implies that correctly identifying problems leads to effective solutions that provide real business value.",\n            "verdict": 1\n        },\n        {\n            "statement": "Theo tài liệu, 80% thành công của dự án AI phụ thuộc vào việc xác định đúng vấn đề.",\n            "reason": "The context explicitly states that 80% of AI project success is due to correctly identifying the problem.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc áp dụng tư duy logic giúp tối ưu hóa quy trình triển khai.",\n            "reason": "The context discusses how logical thinking aids in optimizing processes, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tối ưu hóa quy trình triển khai dẫn đến tiết kiệm thời gian và chi phí.",\n            "reason": "The context mentions that optimizing processes can save time and costs, which supports this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiết kiệm thời gian và chi phí có thể dẫn đến hiệu quả đầu tư cao hơn trong các dự án AI.",\n            "reason": "While the context discusses saving time and costs, it does not explicitly link this to higher investment efficiency in AI projects.",\n            "verdict": 0\n        },\n        {\n            "statement": "Tư duy logic cho phép phân tích vấn đề từ nhiều góc độ khác nhau.",\n            "reason": "The context states that logical thinking allows for multi-dimensional analysis, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Phân tích đa chiều giúp xây dựng giải pháp AI sát thực tế và hiệu quả hơn.",\n            "reason": "The context indicates that multi-dimensional analysis leads to practical and effective AI solutions, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tư duy logic giúp phân biệt giữa các giải pháp thực sự hiệu quả và những xu hướng không thực tế.",\n            "reason": "The context mentions that logical thinking helps distinguish effective solutions from unrealistic trends, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc phân biệt giữa các giải pháp thực sự hiệu quả và những xu hướng không thực tế giúp tránh được việc đầu tư sai hướng và lãng phí nguồn lực.",\n            "reason": "The context implies that distinguishing effective solutions helps avoid misdirected investments and resource waste, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Sử dụng các công cụ như ma trận Tác động-Khả thi giúp xác định ưu tiên cải thiện dữ liệu người dùng.",\n            "reason": "The context discusses using tools like the Impact-Feasibility matrix to prioritize user data improvements, supporting this statement.",\n          ...
# </completion>
# </generation>
#
# <generation number="2">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-CsZG694LN8w3WNkJAnd6ww299Txcx', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "statements": [\n        {\n            "statement": "Tư duy logic và kỹ năng giải quyết vấn đề quan trọng cho việc tối ưu hóa nguồn lực và tăng doanh thu trong các dự án AI.",\n            "reason": "The context emphasizes the importance of logical thinking and problem-solving skills in optimizing resources, but it does not explicitly mention increasing revenue in AI projects.",\n            "verdict": 0\n        },\n        {\n            "statement": "Tư duy logic giúp xác định chính xác vấn đề cần giải quyết.",\n            "reason": "The context states that logical thinking helps identify the right problems, which directly supports this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc xác định đúng vấn đề đảm bảo rằng các giải pháp được phát triển sẽ mang lại giá trị thực sự cho doanh nghiệp.",\n            "reason": "The context indicates that identifying the right problem is crucial for developing solutions that provide real business value, thus supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Theo tài liệu, 80% thành công của dự án AI phụ thuộc vào việc xác định đúng vấn đề.",\n            "reason": "The context explicitly states that 80% of AI project success depends on identifying the right problem, making this statement directly supported.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc áp dụng tư duy logic giúp tối ưu hóa quy trình triển khai.",\n            "reason": "The context discusses the benefits of logical thinking in problem-solving but does not specifically mention optimizing the implementation process.",\n            "verdict": 0\n        },\n        {\n            "statement": "Tối ưu hóa quy trình triển khai dẫn đến tiết kiệm thời gian và chi phí.",\n            "reason": "While the context mentions saving time and costs, it does not directly link this to optimizing the implementation process.",\n            "verdict": 0\n        },\n        {\n            "statement": "Tiết kiệm thời gian và chi phí có thể dẫn đến hiệu quả đầu tư cao hơn trong các dự án AI.",\n            "reason": "The context implies that saving time and costs can lead to better investment efficiency, but it does not explicitly state this connection.",\n            "verdict": 0\n        },\n        {\n            "statement": "Tư duy logic cho phép phân tích vấn đề từ nhiều góc độ khác nhau.",\n            "reason": "The context mentions multi-dimensional analysis as part of logical thinking, which supports this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Phân tích đa chiều giúp xây dựng giải pháp AI sát thực tế và hiệu quả hơn.",\n            "reason": "The context states that multi-dimensional analysis contributes to building practical and effective AI solutions, thus supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tư duy logic giúp phân biệt giữa các giải pháp thực sự hiệu quả và những xu hướng không thực tế.",\n            "reason": "The context discusses distinguishing effective solutions from unrealistic trends, which supports this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc phân biệt giữa các giải pháp thực sự hiệu quả và những xu hướng không thực tế giúp tránh được việc đầu tư sai hướng và lãng phí nguồn lực.",\n            "reason": "The context implies that distinguishing effective solutions helps avoid misdirected investments and resource waste, thus supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Sử dụng các công cụ như ma trận Tác động-Khả thi giúp xác định ưu tiên cải thiện dữ liệu người dùng.",\n            " ...
# </completion>
# </generation>
#
# <generation number="3">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-CsZGQeSaLvd6h0ThRNyGA25oBC2IZ', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "statements": [\n        {\n            "statement": "Tư duy logic và kỹ năng giải quyết vấn đề quan trọng cho việc tối ưu hóa nguồn lực và tăng doanh thu trong các dự án AI.",\n            "reason": "The context emphasizes the importance of logical thinking and problem-solving skills in optimizing resources, but it does not explicitly mention increasing revenue in AI projects.",\n            "verdict": 0\n        },\n        {\n            "statement": "Tư duy logic giúp xác định chính xác vấn đề cần giải quyết.",\n            "reason": "The context states that logical thinking helps identify the right problems, which directly supports this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc xác định đúng vấn đề đảm bảo rằng các giải pháp được phát triển sẽ mang lại giá trị thực sự cho doanh nghiệp.",\n            "reason": "The context implies that correctly identifying problems leads to effective solutions that provide real business value.",\n            "verdict": 1\n        },\n        {\n            "statement": "Theo tài liệu, 80% thành công của dự án AI phụ thuộc vào việc xác định đúng vấn đề.",\n            "reason": "The context explicitly states that 80% of AI project success is due to correctly identifying the problem.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc áp dụng tư duy logic giúp tối ưu hóa quy trình triển khai.",\n            "reason": "The context discusses how logical thinking contributes to optimizing processes, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tối ưu hóa quy trình triển khai dẫn đến tiết kiệm thời gian và chi phí.",\n            "reason": "The context mentions that optimizing processes can save time and costs, which supports this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tiết kiệm thời gian và chi phí có thể dẫn đến hiệu quả đầu tư cao hơn trong các dự án AI.",\n            "reason": "While the context discusses saving time and costs, it does not explicitly link this to higher investment efficiency in AI projects.",\n            "verdict": 0\n        },\n        {\n            "statement": "Tư duy logic cho phép phân tích vấn đề từ nhiều góc độ khác nhau.",\n            "reason": "The context states that logical thinking allows for multi-dimensional analysis, which supports this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Phân tích đa chiều giúp xây dựng giải pháp AI sát thực tế và hiệu quả hơn.",\n            "reason": "The context indicates that multi-dimensional analysis leads to practical and effective AI solutions, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tư duy logic giúp phân biệt giữa các giải pháp thực sự hiệu quả và những xu hướng không thực tế.",\n            "reason": "The context mentions that logical thinking helps distinguish effective solutions from unrealistic trends, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc phân biệt giữa các giải pháp thực sự hiệu quả và những xu hướng không thực tế giúp tránh được việc đầu tư sai hướng và lãng phí nguồn lực.",\n            "reason": "The context implies that distinguishing effective solutions from trends helps avoid misdirected investments and resource waste.",\n            "verdict": 1\n        },\n        {\n            "statement": "Sử dụng các công cụ như ma trận Tác động-Khả thi giúp xác định ưu tiên cải thiện dữ liệu người dùng.",\n            "reason": "The context discusses using tools like the Impact-Feasibility matrix to prioritize user data improvements, supporting this statement.",\n            " ...
# </completion>
# </generation>
#
# </failed_attempts>
#
# <last_exception>
#     The output is incomplete due to a max_tokens length limit.
# </last_exception>)
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# ERROR:ragas.executor:Exception raised in Job[100]: InstructorRetryException(<failed_attempts>
#
# <generation number="1">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-CsZIXXyzyAezfMnkfe0mXRgw9K2Ov', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "statements": [\n        {\n            "statement": "Việc điều chỉnh Adapter-tuning và kỹ thuật LoRA có thể giúp tối ưu hóa tài nguyên trong quá trình fine-tuning các mô hình ngôn ngữ lớn.",\n            "reason": "The context discusses how LoRA and PEFT techniques optimize resource usage during fine-tuning, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc điều chỉnh Adapter-tuning và kỹ thuật LoRA giúp tối ưu hóa tài nguyên thông qua các điểm sau.",\n            "reason": "The context supports the idea that LoRA and Adapter-tuning optimize resources, thus this statement can be inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Giảm số lượng tham số cần điều chỉnh là một trong những điểm.",\n            "reason": "The context mentions that reducing the number of parameters to adjust is a key point of LoRA, making this statement valid.",\n            "verdict": 1\n        },\n        {\n            "statement": "Thay vì cập nhật toàn bộ các tham số của mô hình, LoRA tập trung vào việc tìm kiếm một cấu trúc có hạng thấp cho các ma trận trọng số.",\n            "reason": "This statement is directly supported by the context, which explains LoRA\'s focus on low-rank structures.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc tìm kiếm một cấu trúc có hạng thấp giúp giảm thiểu số lượng tham số cần điều chỉnh.",\n            "reason": "The context states that searching for a low-rank structure minimizes the number of parameters to adjust, confirming this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Giảm thiểu số lượng tham số cần điều chỉnh giúp tiết kiệm tài nguyên.",\n            "reason": "The context implies that reducing the number of parameters saves resources, thus this statement is valid.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tối ưu hóa về mặt tài nguyên và thời gian là một điểm khác.",\n            "reason": "The context mentions optimizing resources and time as benefits of LoRA, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Kỹ thuật LoRA cho phép huấn luyện các mô hình ngôn ngữ lớn một cách tối ưu.",\n            "reason": "The context supports that LoRA allows for optimal training of large language models, confirming this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Kỹ thuật LoRA giúp tận dụng tối đa kiến thức ban đầu từ dữ liệu lớn mà không cần phải huấn luyện lại toàn bộ mô hình.",\n            "reason": "The context states that LoRA allows leveraging initial knowledge without retraining the entire model, making this statement valid.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc không cần phải huấn luyện lại toàn bộ mô hình không chỉ tiết kiệm thời gian mà còn giảm thiểu yêu cầu về GPU mạnh và bộ nhớ lớn.",\n            "reason": "The context mentions that not retraining the entire model saves time and reduces GPU and memory requirements, confirming this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Giảm thiểu nguy cơ quá khớp (overfitting) là một lợi ích khác.",\n            "reason": "The context discusses that reducing the number of parameters helps mitigate overfitting, making this statement valid.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc chỉ điều chỉnh một số lượng nhỏ tham số giúp mô hình dễ dàng tổng quát hơn với dữ liệu mới.",\n            "reason": "The context implies that adjusting fewer parameters aids generalization to new data, confirming this statement.",\n            "verdi ...
# </completion>
# </generation>
#
# <generation number="2">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-CsZIpS5GC4GDIYeLnvPXxn7lbr8ii', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "statements": [\n        {\n            "statement": "Việc điều chỉnh Adapter-tuning và kỹ thuật LoRA có thể giúp tối ưu hóa tài nguyên trong quá trình fine-tuning các mô hình ngôn ngữ lớn.",\n            "reason": "The context discusses how LoRA and PEFT techniques optimize resource usage during fine-tuning, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc điều chỉnh Adapter-tuning và kỹ thuật LoRA giúp tối ưu hóa tài nguyên thông qua các điểm sau.",\n            "reason": "The context supports the idea that LoRA and Adapter-tuning optimize resources, but it does not explicitly list points, making this statement not directly inferred.",\n            "verdict": 0\n        },\n        {\n            "statement": "Giảm số lượng tham số cần điều chỉnh là một trong những điểm.",\n            "reason": "The context mentions that LoRA reduces the number of parameters that need to be adjusted, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Thay vì cập nhật toàn bộ các tham số của mô hình, LoRA tập trung vào việc tìm kiếm một cấu trúc có hạng thấp cho các ma trận trọng số.",\n            "reason": "The context explicitly states that LoRA focuses on finding a low-rank structure for weight matrices instead of updating all parameters, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc tìm kiếm một cấu trúc có hạng thấp giúp giảm thiểu số lượng tham số cần điều chỉnh.",\n            "reason": "The context explains that searching for a low-rank structure minimizes the number of parameters to adjust, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Giảm thiểu số lượng tham số cần điều chỉnh giúp tiết kiệm tài nguyên.",\n            "reason": "The context implies that reducing the number of parameters to adjust leads to resource savings, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tối ưu hóa về mặt tài nguyên và thời gian là một điểm khác.",\n            "reason": "The context mentions optimizing resources and time as benefits of LoRA, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Kỹ thuật LoRA cho phép huấn luyện các mô hình ngôn ngữ lớn một cách tối ưu.",\n            "reason": "The context states that LoRA allows for optimal training of large language models, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Kỹ thuật LoRA giúp tận dụng tối đa kiến thức ban đầu từ dữ liệu lớn mà không cần phải huấn luyện lại toàn bộ mô hình.",\n            "reason": "The context indicates that LoRA leverages initial knowledge from large datasets without retraining the entire model, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc không cần phải huấn luyện lại toàn bộ mô hình không chỉ tiết kiệm thời gian mà còn giảm thiểu yêu cầu về GPU mạnh và bộ nhớ lớn.",\n            "reason": "The context supports that not retraining the entire model saves time and reduces GPU and memory requirements, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Giảm thiểu nguy cơ quá khớp (overfitting) là một lợi ích khác.",\n            "reason": "The context mentions that reducing the number of parameters helps mitigate overfitting, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc chỉ điều chỉn ...
# </completion>
# </generation>
#
# <generation number="3">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-CsZJ7vDsQdT2AZpgrKKbeVisSMkOJ', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "statements": [\n        {\n            "statement": "Việc điều chỉnh Adapter-tuning và kỹ thuật LoRA có thể giúp tối ưu hóa tài nguyên trong quá trình fine-tuning các mô hình ngôn ngữ lớn.",\n            "reason": "The context discusses how LoRA and PEFT techniques optimize resource usage during fine-tuning, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc điều chỉnh Adapter-tuning và kỹ thuật LoRA giúp tối ưu hóa tài nguyên thông qua các điểm sau.",\n            "reason": "The context supports the idea that Adapter-tuning and LoRA optimize resources, but it does not explicitly list points, making this statement not directly inferred.",\n            "verdict": 0\n        },\n        {\n            "statement": "Giảm số lượng tham số cần điều chỉnh là một trong những điểm.",\n            "reason": "The context mentions that reducing the number of parameters to adjust is a benefit of LoRA, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Thay vì cập nhật toàn bộ các tham số của mô hình, LoRA tập trung vào việc tìm kiếm một cấu trúc có hạng thấp cho các ma trận trọng số.",\n            "reason": "The context explicitly states that LoRA focuses on finding a low-rank structure instead of updating all parameters, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc tìm kiếm một cấu trúc có hạng thấp giúp giảm thiểu số lượng tham số cần điều chỉnh.",\n            "reason": "The context explains that searching for a low-rank structure minimizes the number of parameters to adjust, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Giảm thiểu số lượng tham số cần điều chỉnh giúp tiết kiệm tài nguyên.",\n            "reason": "The context implies that reducing the number of parameters to adjust leads to resource savings, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Tối ưu hóa về mặt tài nguyên và thời gian là một điểm khác.",\n            "reason": "The context mentions optimizing resources and time as a benefit of LoRA, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Kỹ thuật LoRA cho phép huấn luyện các mô hình ngôn ngữ lớn một cách tối ưu.",\n            "reason": "The context states that LoRA allows for optimal training of large language models, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Kỹ thuật LoRA giúp tận dụng tối đa kiến thức ban đầu từ dữ liệu lớn mà không cần phải huấn luyện lại toàn bộ mô hình.",\n            "reason": "The context indicates that LoRA leverages initial knowledge from large datasets without retraining the entire model, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc không cần phải huấn luyện lại toàn bộ mô hình không chỉ tiết kiệm thời gian mà còn giảm thiểu yêu cầu về GPU mạnh và bộ nhớ lớn.",\n            "reason": "The context supports that not retraining the entire model saves time and reduces GPU and memory requirements, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Giảm thiểu nguy cơ quá khớp (overfitting) là một lợi ích khác.",\n            "reason": "The context mentions that reducing the number of parameters helps mitigate overfitting, making this statement directly inferred.",\n            "verdict": 1\n        },\n        {\n            "statement": "Việc chỉ điều chỉnh một số lượng nh ...
# </completion>
# </generation>
#
# </failed_attempts>
#
# <last_exception>
#     The output is incomplete due to a max_tokens length limit.
# </last_exception>)
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# ERROR:ragas.executor:Exception raised in Job[108]: InstructorRetryException(<failed_attempts>
#
# <generation number="1">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-CsZKRVV82MwpoHRAPC2unHDilLCAO', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "statements": [\n        {\n            "statement": "Để sử dụng hàm trong Streamlit nhằm tạo giao diện ứng dụng và xử lý tính toán giai thừa, cần thực hiện theo các bước sau.",\n            "reason": "The context discusses the use of Streamlit for creating an application interface and performing factorial calculations, which aligns with the statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Bước đầu tiên là tạo giao diện người dùng.",\n            "reason": "The context implies that creating a user interface is part of the process, making this statement directly inferable.",\n            "verdict": 1\n        },\n        {\n            "statement": "Sử dụng `st.title(\\"...\\")` để tạo tiêu đề cho ứng dụng.",\n            "reason": "The context explicitly mentions using `st.title()` to create a title for the application, confirming the statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Sử dụng `st.text_input(\\"Nhập số:\\")` để cho phép người dùng nhập số mà người dùng muốn tính giai thừa.",\n            "reason": "The context describes using `st.text_input()` for user input, which directly supports this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Sử dụng `st.button(\\"Caculate\\")` để tạo nút bấm cho phép thực thi hành động khi người dùng nhấn vào.",\n            "reason": "The context mentions creating a button for user interaction, which validates this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Bước thứ hai là xử lý tính toán giai thừa.",\n            "reason": "The context outlines steps for processing factorial calculations, making this statement directly inferable.",\n            "verdict": 1\n        },\n        {\n            "statement": "Khi nút bấm được nhấn, cần kiểm tra sự kiện click và thực hiện tính toán giai thừa cho số mà người dùng đã nhập.",\n            "reason": "The context indicates that clicking the button triggers the factorial calculation, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Sử dụng hàm `st.write()` để hiển thị kết quả ra màn hình.",\n            "reason": "The context explicitly states that `st.write()` is used to display results, confirming the statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Bước thứ ba là ví dụ mã lệnh.",\n            "reason": "The context discusses providing code examples, which aligns with this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Mã lệnh bao gồm việc nhập thư viện Streamlit và math.",\n            "reason": "The context mentions importing Streamlit and math libraries, validating this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Sử dụng `st.title(\\"Ứng dụng Tính Giai Thừa\\")` để tạo tiêu đề cho ứng dụng.",\n            "reason": "The context specifies using `st.title()` to create a title for the factorial application, confirming the statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Sử dụng `st.text_input(\\"Nhập số:\\")` để cho phép người dùng nhập số.",\n            "reason": "The context reiterates the use of `st.text_input()` for user input, which supports this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Nếu nút bấm `st.button(\\"Caculate\\")` được nhấn, cần kiểm tra xem số đã nhập có phải là số nguyên dương hay không.",\n            "reason": "The context discusses checking if the input number is a positive integer when the button is pressed, validating this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "Nếu số  ...
# </completion>
# </generation>
#
# <generation number="2">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
# ...
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# ERROR:ragas.executor:Exception raised in Job[184]: InstructorRetryException(<failed_attempts>
#
# <generation number="1">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-CsZV0JsHuKV02uxiGg7RxNjOEY3Xe', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "statements": [\n        {\n            "statement": "The key factors in evaluating the feasibility of AI projects are based on three aspects: technical, resource, and organizational.",\n            "reason": "The context explicitly states that the evaluation of AI projects is based on these three aspects.",\n            "verdict": 1\n        },\n        {\n            "statement": "The technical aspect includes data availability and quality.",\n            "reason": "The context lists data availability and quality as part of the technical aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The technical aspect includes algorithm complexity.",\n            "reason": "The context mentions algorithm complexity as part of the technical aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The technical aspect includes infrastructure requirements.",\n            "reason": "The context includes infrastructure requirements as part of the technical aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The technical aspect includes integration challenges.",\n            "reason": "The context lists integration challenges as part of the technical aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The resource aspect includes team skills and capacity.",\n            "reason": "The context mentions team skills and capacity as part of the resource aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The resource aspect includes budget requirements.",\n            "reason": "The context includes budget requirements as part of the resource aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The resource aspect includes timeline constraints.",\n            "reason": "The context lists timeline constraints as part of the resource aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The resource aspect includes external dependencies.",\n            "reason": "The context mentions external dependencies as part of the resource aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The organizational aspect includes stakeholder buy-in.",\n            "reason": "The context includes stakeholder buy-in as part of the organizational aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The organizational aspect includes change management.",\n            "reason": "The context mentions change management as part of the organizational aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The organizational aspect includes regulatory approval.",\n            "reason": "The context lists regulatory approval as part of the organizational aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The organizational aspect includes cultural fit.",\n            "reason": "The context includes cultural fit as part of the organizational aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The scoring system used for assessing feasibility ranges from 1 to 5.",\n            "reason": "The context explicitly states that the scoring system for feasibility assessment ranges from 1 to 5.",\n            "verdict": 1\n        },\n        {\n            "statement": "A score of 5 indicates very easy.",\n            "reason": "The context defines that a score of 5 indicates very easy.",\n            "verdict": 1\n        },\n        {\n            "statement": "A score of 4 indicates easy.",\n            "reason": "The context defines that a score of 4 indicates easy.",\n            "verdict": 1\n        },\n        {\ ...
# </completion>
# </generation>
#
# <generation number="2">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-CsZVKZD3RhCYq0U45uOuJtH11HmwA', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "statements": [\n        {\n            "statement": "The key factors in evaluating the feasibility of AI projects are based on three aspects: technical, resource, and organizational.",\n            "reason": "The context explicitly states that the feasibility of AI projects is evaluated based on these three aspects.",\n            "verdict": 1\n        },\n        {\n            "statement": "The technical aspect includes data availability and quality.",\n            "reason": "The context lists data availability and quality as part of the technical aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The technical aspect includes algorithm complexity.",\n            "reason": "The context mentions algorithm complexity as a factor under the technical aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The technical aspect includes infrastructure requirements.",\n            "reason": "The context includes infrastructure requirements as part of the technical aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The technical aspect includes integration challenges.",\n            "reason": "The context lists integration challenges as part of the technical aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The resource aspect includes team skills and capacity.",\n            "reason": "The context explicitly states that team skills and capacity are part of the resource aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The resource aspect includes budget requirements.",\n            "reason": "The context mentions budget requirements as part of the resource aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The resource aspect includes timeline constraints.",\n            "reason": "The context includes timeline constraints as part of the resource aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The resource aspect includes external dependencies.",\n            "reason": "The context lists external dependencies as part of the resource aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The organizational aspect includes stakeholder buy-in.",\n            "reason": "The context explicitly states that stakeholder buy-in is part of the organizational aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The organizational aspect includes change management.",\n            "reason": "The context mentions change management as part of the organizational aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The organizational aspect includes regulatory approval.",\n            "reason": "The context includes regulatory approval as part of the organizational aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The organizational aspect includes cultural fit.",\n            "reason": "The context lists cultural fit as part of the organizational aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The scoring system used for assessing feasibility ranges from 1 to 5.",\n            "reason": "The context explicitly states that the scoring system for feasibility assessment ranges from 1 to 5.",\n            "verdict": 1\n        },\n        {\n            "statement": "A score of 5 indicates very easy.",\n            "reason": "The context defines that a score of 5 indicates very easy.",\n            "verdict": 1\n        },\n        {\n            "statement": "A score of 4 indicates easy.",\n            "reason": "The context defines that a score of 4 indicates easy.",\n  ...
# </completion>
# </generation>
#
# <generation number="3">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-CsZVcOoynrfInLmNbe8uH3dDWBOuD', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "statements": [\n        {\n            "statement": "The key factors in evaluating the feasibility of AI projects are based on three aspects: technical, resource, and organizational.",\n            "reason": "The context explicitly states that the feasibility of AI projects is evaluated based on three main factors: Technical, Resource, and Organizational.",\n            "verdict": 1\n        },\n        {\n            "statement": "The technical aspect includes data availability and quality.",\n            "reason": "The context lists data availability and quality as part of the technical aspect of feasibility evaluation.",\n            "verdict": 1\n        },\n        {\n            "statement": "The technical aspect includes algorithm complexity.",\n            "reason": "The context mentions algorithm complexity as a factor under the technical aspect.",\n            "verdict": 1\n        },\n        {\n            "statement": "The technical aspect includes infrastructure requirements.",\n            "reason": "Infrastructure requirements are explicitly mentioned as part of the technical aspect in the context.",\n            "verdict": 1\n        },\n        {\n            "statement": "The technical aspect includes integration challenges.",\n            "reason": "Integration challenges are listed as part of the technical aspect in the context.",\n            "verdict": 1\n        },\n        {\n            "statement": "The resource aspect includes team skills and capacity.",\n            "reason": "The context states that team skills and capacity are part of the resource aspect of feasibility evaluation.",\n            "verdict": 1\n        },\n        {\n            "statement": "The resource aspect includes budget requirements.",\n            "reason": "Budget requirements are explicitly mentioned as part of the resource aspect in the context.",\n            "verdict": 1\n        },\n        {\n            "statement": "The resource aspect includes timeline constraints.",\n            "reason": "Timeline constraints are listed as part of the resource aspect in the context.",\n            "verdict": 1\n        },\n        {\n            "statement": "The resource aspect includes external dependencies.",\n            "reason": "External dependencies are mentioned as part of the resource aspect in the context.",\n            "verdict": 1\n        },\n        {\n            "statement": "The organizational aspect includes stakeholder buy-in.",\n            "reason": "Stakeholder buy-in is explicitly mentioned as part of the organizational aspect in the context.",\n            "verdict": 1\n        },\n        {\n            "statement": "The organizational aspect includes change management.",\n            "reason": "Change management is listed as part of the organizational aspect in the context.",\n            "verdict": 1\n        },\n        {\n            "statement": "The organizational aspect includes regulatory approval.",\n            "reason": "Regulatory approval is mentioned as part of the organizational aspect in the context.",\n            "verdict": 1\n        },\n        {\n            "statement": "The organizational aspect includes cultural fit.",\n            "reason": "Cultural fit is explicitly mentioned as part of the organizational aspect in the context.",\n            "verdict": 1\n        },\n        {\n            "statement": "The scoring system used for assessing feasibility ranges from 1 to 5.",\n            "reason": "The context clearly states that the scoring system for feasibility assessment ranges from 1 to 5.",\n            "verdict": 1\n        },\n        {\n            "statement": "A score of 5 indicates very easy.",\n            "reason": "The context defines that a score of 5 indicates very easy in the scoring s ...
# </completion>
# </generation>
#
# </failed_attempts>
#
# <last_exception>
#     The output is incomplete due to a max_tokens length limit.
# </last_exception>)
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# WARNING:ragas.prompt.pydantic_prompt:LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# Evaluation completed in 1755.2 seconds
#   Average: 33.75s per sample
# ==================================================
# === RAGAS SCORES (Cross-Encoder Reranking) ===
# ==================================================
# {'faithfulness': 0.7646, 'answer_relevancy': 0.6121, 'context_precision': 0.8237, 'context_recall': 0.7061}

# %% [markdown]
# ### *6.4 Visualize evaluation results

# %%
results_df = ragas_results.to_pandas()
pdf_filename = "RAGAS_Evaluation_Report_CrossEncoder.pdf"

with PdfPages(pdf_filename) as pdf:
    sns.set_style("whitegrid")
    fig1 = plt.figure(figsize=(8, 8))

    metric_cols = [col for col in ['faithfulness', 'answer_relevancy', 'context_precision', 'context_recall']
                   if col in results_df.columns]

    if metric_cols:
        scores = {col: results_df[col].mean() for col in metric_cols}
        plt.bar(scores.keys(), scores.values(), color='coral', edgecolor='darkred', alpha=0.7)
        plt.title(f"RAGAS Scores (Cross-Encoder: {RERANKER_MODEL})", fontsize=14, fontweight='bold')
        plt.ylabel("Score (0-1)")
        plt.ylim(0, 1)
        plt.legend()

    if metric_cols:
        stats_df = results_df[metric_cols].describe().round(3)
        fig2 = plt.figure(figsize=(10, 6))
        plt.axis('off')
        plt.title("Detailed Statistics (Cross-Encoder Reranking)", fontsize=16, fontweight='bold', pad=20)

        table = plt.table(cellText=stats_df.values,
                          colLabels=stats_df.columns,
                          rowLabels=stats_df.index,
                          loc='center',
                          cellLoc='center')
        table.auto_set_font_size(False)
        table.set_fontsize(10)
        table.scale(1.2, 1.2)

        pdf.savefig(fig2)
        plt.close(fig2)

print(f"PDF saved: {pdf_filename}")
# Out:
# /tmp/ipython-input-4243833182.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# PDF saved: RAGAS_Evaluation_Report_CrossEncoder.pdf
